# %% [markdown]
# # **Model Selection**

# %%
#import necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
from sklearn.decomposition import PCA
import category_encoders as ce
from sklearn.model_selection import GridSearchCV
import pickle

# %% [markdown]
# ## **Load the Data**
#
# **NOTE :-** We have loaded the data from the feature-selection notebook.
#
# - **We want to create a scikit-learn pipeline that will handle all the steps needed to prepare the data and build the model. This includes changing categorical data to numerical data, applying encoding techniques, and building the model etc.**
#
# - **By using this pipeline, we don't need to save the data after each step, making the process simpler and more efficient.**

# %%
input = '../data/clean-data/flats-house-cleaned-v6.csv'

df = pd.read_csv(input)

print("Shape of the data : ",df.shape)
df.head()
# Out:
# Shape of the data :  (3540, 13)
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat   sector 77   1.50        3         3       3  Relatively New
# 1          flat  sector 108   0.85        3         3       2  Relatively New
# 2          flat   sector 12   0.60        2         2       1    New Property
# 3          flat  sector 99a   0.30        2         1       0    New Property
# 4          flat  sector 102   1.55        3         4       3  Relatively New
#
#    built_up_area  servant room  store room  furnishing_type luxury_category  \
# 0         1310.0             0           0                2          Medium
# 1         1500.0             1           0                0          Medium
# 2          800.0             0           0                1             Low
# 3          500.0             0           0                0             Low
# 4         1315.0             1           0                2            High
#
#   floor_category
# 0      Mid Floor
# 1      Low Floor
# 2      Low Floor
# 3     High Floor
# 4      Mid Floor

# %%
# furnishing_type column has 3 categories
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 0    2368
# 2     987
# 1     185
# Name: count, dtype: int64

# %% [markdown]
# - 0 -> unfurnished
#
# - 1 -> semifurnished
#
# - 2 -> furnished

# %%
# converting furnishing_type column to categorical
df['furnishing_type'] = df['furnishing_type'].replace({0.0:'unfurnished',1.0:'semifurnished',2.0:'furnished'})
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat   sector 77   1.50        3         3       3  Relatively New
# 1          flat  sector 108   0.85        3         3       2  Relatively New
# 2          flat   sector 12   0.60        2         2       1    New Property
# 3          flat  sector 99a   0.30        2         1       0    New Property
# 4          flat  sector 102   1.55        3         4       3  Relatively New
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0         1310.0             0           0       furnished          Medium
# 1         1500.0             1           0     unfurnished          Medium
# 2          800.0             0           0   semifurnished             Low
# 3          500.0             0           0     unfurnished             Low
# 4         1315.0             1           0       furnished            High
#
#   floor_category
# 0      Mid Floor
# 1      Low Floor
# 2      Low Floor
# 3     High Floor
# 4      Mid Floor

# %% [markdown]
# ---

# %% [markdown]
# ## **Outline** :
#
# - We will use three techniques to encode the categorical variables and then we will compare R2-scores.
#
# 1. `Ordinal Encoding` : [ Works well with tree based models ]
#
# 2. `OneHotEncoding` : [ Works well with linear models ]
#
# 3. `Target Encoding` : [ Works well with tree based models ]
#
# - The encoding technique which gives the best R2-score , We will use that encoding technique to build the model.

# %%
X = df.drop(columns=['price'])
y = df['price']

# Since  price have skewed distribtuion , we need to apply the log1p transformation to it
y_transformed = np.log1p(y)

# %% [markdown]
# ### **1 .Ordinal Encoding**

# %%
# Standard Scaling to Numerical columns
numerical_columns = ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']


# List of columns that need to be encoded
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Create a column transformer for preprocessing
preprocessor1 = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_columns),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode)
    ], 
    remainder='passthrough'  # Keep other columns as they are
)

# Create a pipeline with preprocessing and linear regression
pipeline1 = Pipeline([
    ('preprocessor1', preprocessor1),
    ('regressor', LinearRegression())
])
pipeline1
# Out:
# Pipeline(steps=[('preprocessor1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category'])])),
#                 ('regressor', LinearRegression())])

# %%
# We will train & evaluate the model using K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores1 = cross_val_score(pipeline1, X, y_transformed, cv=kfold, scoring='r2')

print("\n\n***** With Ordinal Encoding : *****")
print("  Mean of R2-score : ",scores1.mean())
print("  std of R2-score :  ",scores1.std())
# Out:
# ***** With Ordinal Encoding : *****
#   Mean of R2-score :  0.7358613112250211
#   std of R2-score :   0.02594730292611873

# %% [markdown]
# - **Observation :- On average, Using `Ordinal Encoding` our Linear Regression  model is giving R2-Score of 73.58 . Which is not good.**

# %% [markdown]
# - **Now , We also want to test  `Mean Absolute Error` because we are doing a predictive task. Along with  R2-Score,We also want to check MAE of our Model**

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# Fitting the pipeline on the training data
pipeline1.fit(X_train,y_train)

# Predicting the target variable for the test set
y_pred = pipeline1.predict(X_test)


# Applying the inverse of the log1p transformation to the predictions using expm1
# expm1(x) is equivalent to exp(x) - 1, which reverses the log1p transformation
y_pred = np.expm1(y_pred)

# Calculating the mean absolute error between the actual and predicted values
mae1 = mean_absolute_error(np.expm1(y_test),y_pred)
print(" With Ordinal Encoding, MAE of Linear Regression : ",mae1)
# Out:
#  With Ordinal Encoding, MAE of Linear Regression :  0.8229967588204127

# %% [markdown]
#  - On average, our Linear Regression with With Ordinal Encoding, is giving 0.82 crore (82lakhs)  as Mean Absolute Error.
#
# - It means that, if the actual price is 100 Lakhs, our model is predicting it around 182 Lakhs.
#
# - This is not a good MAE. We need to improve this model.

# %% [markdown]
# **Defining a function to evaluate the different model all at once**
#
# - This function takes the model name and the model itself as input.
# - It returns a list containing the model name, mean R2 score, and MAE

# %%
def scorer1(model_name, model):

    output1 = []

    output1.append(model_name)
    
    # Create a pipeline with the preprocessor1 and the given model
    pipeline1 = Pipeline([
        ('preprocessor1', preprocessor1),
        ('regressor', model)
    ])
    
    # Perform K-fold cross-validation with 10 splits
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores1 = cross_val_score(pipeline1, X, y_transformed, cv=kfold, scoring='r2')
    
    # Append the mean R2 score to the output list
    output1.append(scores1.mean())
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y_transformed, test_size=0.2, random_state=42)
    
    # Fit the pipeline on the training data
    pipeline1.fit(X_train, y_train)
    
    # Predict the target variable for the test set
    y_pred = pipeline1.predict(X_test)
    
    # Apply the inverse of the log1p transformation to the predictions
    y_pred = np.expm1(y_pred)
    
    # Calculate the mean absolute error between the actual and predicted values
    output1.append(mean_absolute_error(np.expm1(y_test), y_pred))

    return output1

# %%
# Dictionary to store different regression models
model_dict1   = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# List to store the output of the scorer function for each model
model_output1 = []
for model_name,model in model_dict1.items():
    model_output1.append(scorer1(model_name, model))

# Create a DataFrame from the model output
model_df1 = pd.DataFrame(model_output1, columns=['name','r2','mae'])
# Sort the DataFrame by mean absolute error (mae)
model_df1.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.894049  0.478116
# 5       random forest  0.883361  0.494948
# 7   gradient boosting  0.872523  0.536754
# 6         extra trees  0.867541  0.543350
# 9                 mlp  0.785731  0.745781
# 4       decision tree  0.777207  0.788675
# 1                 svr  0.749947  0.817311
# 8            adaboost  0.757777  0.821790
# 2               ridge  0.735864  0.822951
# 0          linear_reg  0.735861  0.822997
# 3               LASSO  0.051530  1.487614

# %% [markdown]
# - **Observation** :  With `Ordinal Encoding`, without any hyperparameter tuning, tree-based models such as xgboost, random forest, and gradient boosting are giving the best R2-score and MAE.

# %% [markdown]
# ---

# %% [markdown]
# ---
# ### **2. OneHotEncoding**
#
# - With Ordinal Encoding of nominal catoegoty of data , Linear regression models treat ordinal and nominal variables differently.
#
# - They compare Ordinal Encoding of nominal variables with each other and develop bias towards a category.
#
# - So, we need to use OneHotEncoding for nominal variables and Ordinal Encoding for ordinal variables.

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat   sector 77   1.50        3         3       3  Relatively New
# 1          flat  sector 108   0.85        3         3       2  Relatively New
# 2          flat   sector 12   0.60        2         2       1    New Property
# 3          flat  sector 99a   0.30        2         1       0    New Property
# 4          flat  sector 102   1.55        3         4       3  Relatively New
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0         1310.0             0           0       furnished          Medium
# 1         1500.0             1           0     unfurnished          Medium
# 2          800.0             0           0   semifurnished             Low
# 3          500.0             0           0     unfurnished             Low
# 4         1315.0             1           0       furnished            High
#
#   floor_category
# 0      Mid Floor
# 1      Low Floor
# 2      Low Floor
# 3     High Floor
# 4      Mid Floor

# %% [markdown]
# **NOTE** :- We are applying Ordinal Encoding as well as OnehotEncoding on these features : -
#
# `sector`,`agePossession`,`furnishing_type`
#
# - ideally Linear model preformance should increase after applying OneHotEncoding on nominal data

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='sklearn.preprocessing._encoders')



# Standard Scaling to Numerical columns
numerical_columns = ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']


# List of columns that need to be encoded
columns_to_encode = ['property_type', 'balcony',  'luxury_category', 'floor_category']

# nominal encoding on nominal columns
nominal_columns =['sector','agePossession','furnishing_type']


# Creating a column transformer for preprocessing
preprocessor2 = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(),  numerical_columns),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',handle_unknown='ignore'), nominal_columns)
    ], 
    remainder='passthrough'
)

# Creating a pipeline
pipeline2 = Pipeline([
    ('preprocessor2', preprocessor2),
    ('regressor', LinearRegression())
])
pipeline2
# Out:
# Pipeline(steps=[('preprocessor2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'balcony',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sector', 'agePossession',
#                                                    'furnishing_type'])])),
#                 ('regressor', LinearRegression())])

# %%
# We will train & evaluate the model using K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores2 = cross_val_score(pipeline2, X, y_transformed, cv=kfold, scoring='r2')

print("\n\n***** With Ordinal Encoding : *****")
print("  Mean of R2-score : ",scores2.mean())
print("  std of R2-score :  ",scores2.std())
# Out:
# ***** With Ordinal Encoding : *****
#   Mean of R2-score :  0.8558795139847366
#   std of R2-score :   0.026661267669432154

# %% [markdown]
# - **Observation :- On average, Using `Ordinal Encoding` for Ordinal Data and `OneHotEncoding` for Nominal Data our Linear Regression  model is giving R2-Score of 0.85 , which is better than earlier case**

# %% [markdown]
# - **Now , We also want to test  `Mean Absolute Error` because we are doing a predictive task. Along with  R2-Score,We also want to check MAE of our Model**

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# Fitting the pipeline on the training data
pipeline2.fit(X_train,y_train)

# Predicting the target variable for the test set
y_pred = pipeline2.predict(X_test)


# Applying the inverse of the log1p transformation to the predictions using expm1
# expm1(x) is equivalent to exp(x) - 1, which reverses the log1p transformation
y_pred = np.expm1(y_pred)

# Calculating the mean absolute error between the actual and predicted values
mae2 = mean_absolute_error(np.expm1(y_test),y_pred)

print(" With OneHot Encoding for Nomial Columns, MAE of Linear Regression : ",mae2)
# Out:
#  With OneHot Encoding for Nomial Columns, MAE of Linear Regression :  0.5869611392076194

# %% [markdown]
#  - On average, our Linear Regression with With OHE, is giving 0.58 crore (58lakhs)  as Mean Absolute Error.
#
# - It means that, if the actual price is 100 Lakhs, our model is predicting it around 158 Lakhs.
#
# - This is better than earlier case.

# %% [markdown]
# **Defining a function `scorer2()` to evaluate the different model all at once**
#
# - This function takes the model name and the model itself as input.
# - It returns a list containing the model name, mean R2 score, and MAE

# %%
def scorer2(model_name, model):

    output2 = []

    output2.append(model_name)
    
    # Create a pipeline with the preprocessor and the given model
    pipeline2 = Pipeline([
        ('preprocessor2', preprocessor2),
        ('regressor', model)
    ])
    
    # Perform K-fold cross-validation with 10 splits
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores2 = cross_val_score(pipeline2, X, y_transformed, cv=kfold, scoring='r2')
    
    # Append the mean R2 score to the output list
    output2.append(scores2.mean())
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y_transformed, test_size=0.2, random_state=42)
    
    # Fit the pipeline on the training data
    pipeline2.fit(X_train, y_train)
    
    # Predict the target variable for the test set
    y_pred = pipeline2.predict(X_test)
    
    # Apply the inverse of the log1p transformation to the predictions
    y_pred = np.expm1(y_pred)
    
    # Calculate the mean absolute error between the actual and predicted values
    output2.append(mean_absolute_error(np.expm1(y_test), y_pred))

    return output2

# %%
# Dictionary to store different regression models
model_dict2 = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# List to store the output of the scorer2() function for each model
model_output2 = []
for model_name,model in model_dict2.items():
    model_output2.append(scorer2(model_name, model))

# Create a DataFrame from the model output
model_df2 = pd.DataFrame(model_output2, columns=['name','r2','mae'])
# Sort the DataFrame by mean absolute error (mae)
model_df2.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.887554  0.486107
# 10            xgboost  0.889682  0.500891
# 9                 mlp  0.876468  0.526064
# 5       random forest  0.873872  0.528106
# 1                 svr  0.883263  0.548790
# 7   gradient boosting  0.855538  0.572256
# 0          linear_reg  0.855880  0.586961
# 2               ridge  0.856342  0.593154
# 4       decision tree  0.778979  0.661283
# 8            adaboost  0.729137  0.865873
# 3               LASSO -0.000949  1.513728

# %% [markdown]
# - **Observation** :  With `OneHotEncoding` to nominal columns, without any hyperparameter tuning, Linear Regression model preformance is better than earlier case, still tree-based models are giving better performance.
#
# - **Improvement**:  One Hot Encoding is not good for `agePossession`,`sector` column because it is creating too many columns; So we can apply PCA on these columns.

# %% [markdown]
# ---

# %% [markdown]
# ---
# ### **3 .OneHotEncoding With PCA**
#
# - One Hot Encoding is not good for `agePossession`,`sector` column because it is creating too many columns; So we can apply PCA on these columns.

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='sklearn.preprocessing._encoders')



# Standard Scaling to Numerical columns
numerical_columns = ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']


# List of columns that need to be encoded
columns_to_encode = ['property_type', 'balcony',  'luxury_category', 'floor_category']

# nominal encoding on nominal columns
nominal_columns =['sector','agePossession','furnishing_type']


# Creating a column transformer for preprocessing
preprocessor3 = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(),  numerical_columns),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',handle_unknown='ignore'), nominal_columns)
    ], 
    remainder='passthrough'
)



# PCA (Principal Component Analysis) is used here to reduce the number of features while retaining 95% of the variance in the data.
pipeline3 = Pipeline([
    ('preprocessor', preprocessor3),
    ('pca', PCA(n_components=min(len(X), len(X.columns)) - 1)),
    ('regressor', LinearRegression())
])

pipeline3
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'balcony',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sector', 'agePossession',
#                                                    'furnishing_type'])])),
#                 ('pca', PCA(n_components=11)),
#                 ('regressor', LinearRegression())])

# %%
# We will train & evaluate the model using K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores3 = cross_val_score(pipeline3, X, y_transformed, cv=kfold, scoring='r2')

print("\n\n***** With OneHotEncoding & PCA : *****")
print("  Mean of R2-score : ",scores3.mean())
print("  std of R2-score :  ",scores3.std())
# Out:
# ***** With OneHotEncoding & PCA : *****
#   Mean of R2-score :  0.731833447821159
#   std of R2-score :   0.02750310063708519

# %% [markdown]
# **Onbervation :** After Applying `OneHotEncoding` & `PCA` Linear Model performace get poor; It is worst than first case.

# %% [markdown]
# - **Now , We also want to test  `Mean Absolute Error` because we are doing a predictive task. Along with  R2-Score,We also want to check MAE of our Model**

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# Fitting the pipeline on the training data
pipeline3.fit(X_train,y_train)

# Predicting the target variable for the test set
y_pred = pipeline3.predict(X_test)


# Applying the inverse of the log1p transformation to the predictions using expm1
# expm1(x) is equivalent to exp(x) - 1, which reverses the log1p transformation
y_pred = np.expm1(y_pred)

# Calculating the mean absolute error between the actual and predicted values
mae3 = mean_absolute_error(np.expm1(y_test),y_pred)

print(" With OneHot Encoding & PCA, MAE of Linear Regression : ",mae3)
# Out:
#  With OneHot Encoding & PCA, MAE of Linear Regression :  0.8283181698052354

# %% [markdown]
# - MAE is also not good after applying `OneHotEncoding` & `PCA`.

# %% [markdown]
# **Note :** To Know about other model performace in this case ,we are trying different model again.

# %%
def scorer3(model_name, model):
    
    output3 = []
    
    output3.append(model_name)
    
    pipeline3 = Pipeline([
        ('preprocessor3', preprocessor3),
        ('pca', PCA(n_components=min(len(X), len(X.columns)) - 1)),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores3 = cross_val_score(pipeline3, X, y_transformed, cv=kfold, scoring='r2')
    
    output3.append(scores3.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline3.fit(X_train,y_train)
    
    y_pred = pipeline3.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output3.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output3

# %%
# Dictionary to store different regression models
from xgboost import XGBRegressor


model_dict3 = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# List to store the output of the scorer2() function for each model
model_output3 = []
for model_name,model in model_dict3.items():
    model_output3.append(scorer3(model_name, model))

# Create a DataFrame from the model output
model_df3 = pd.DataFrame(model_output3, columns=['name','r2','mae'])
# Sort the DataFrame by mean absolute error (mae)
model_df3.sort_values(['mae'])
# Out:
# /home/jasmine/project/real-estate/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/jasmine/project/real-estate/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/jasmine/project/real-estate/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#                  name        r2       mae
# 6         extra trees  0.782047  0.746993
# 5       random forest  0.780603  0.758135
# 10            xgboost  0.771490  0.767597
# 1                 svr  0.787326  0.772981
# 7   gradient boosting  0.772721  0.779202
# 9                 mlp  0.780487  0.784988
# 2               ridge  0.731836  0.828290
# 0          linear_reg  0.731833  0.828318
# 8            adaboost  0.651020  0.963834
# 4       decision tree  0.585352  1.014303
# 3               LASSO -0.000949  1.513728

# %% [markdown]
# - **Observation :**  After applying `OneHotEncoding` & `PCA`, `Target Encoding` , Other models are also not giving better performance as compare earlier case
#
# - **Improvement :** We can look deeper, about this issue ,We can try to apply `Target Encoding` on `sector` column.

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ### **4 .Target Encoding**

# %% [markdown]
# - **Target Encoding** is used to encode the nominal categorical variables in the dataset which have high cardinality, such as `sector` column.

# %% [markdown]
# **NOTE : Data Leakage is very strong problem , so be careful with target encoding. if we use target encoding before train test split , then It might be the case of data leakage**
#
#
# **Here we are using K-fold cross validation so data leakage is not a problem.**

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='sklearn.preprocessing._encoders')


# Standard Scaling to Numerical columns
numerical_columns = ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']

# List of columns that need to be encoded
columns_to_encode = ['property_type', 'balcony',  'luxury_category', 'floor_category']

# nominal encoding on nominal columns
nominal_columns =['agePossession','furnishing_type']

# target encoding on sector column
target_encoding_column = ['sector']

# Creating a column transformer for preprocessing
preprocessor4 = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_columns),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),nominal_columns),
        ('target_enc', ce.TargetEncoder(), target_encoding_column)
    ], 
    remainder='passthrough'
)

# Creating a pipeline
pipeline4 = Pipeline([
    ('preprocessor', preprocessor4),
    ('regressor', LinearRegression())
])
pipeline4
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'balcony',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['agePossession',
#                                                    'furnishing_type']),
#                                                  ('target_enc', TargetEncoder(),
#                                                   ['sector'])])),
#                 ('regressor', LinearRegression())])

# %%
# We will train & evaluate the model using K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores4 = cross_val_score(pipeline4, X, y_transformed, cv=kfold, scoring='r2')

print("\n\n***** With Target Encoding: *****")
print("  Mean of R2-score : ",scores4.mean())
print("  std of R2-score :  ",scores4.std())
# Out:
# ***** With Target Encoding: *****
#   Mean of R2-score :  0.8253249002234087
#   std of R2-score :   0.02672997295015941

# %% [markdown]
# **Observation** : Target Encoding is giving better performance .

# %% [markdown]
# **Defining a function `scorer4()` to evaluate the different model all at once**
#
# - This function takes the model name and the model itself as input.
# - It returns a list containing the model name, mean R2 score, and MAE

# %%
def scorer4(model_name, model):
    
    output4 = []
    
    output4.append(model_name)
    
    pipeline4 = Pipeline([
        ('preprocessor', preprocessor4),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores4 = cross_val_score(pipeline4, X, y_transformed, cv=kfold, scoring='r2')

    output4.append(scores4.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline4.fit(X_train,y_train)
    
    y_pred = pipeline4.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output4.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output4

# %%
# Dictionary to store different regression models
from xgboost import XGBRegressor


model_dict4 = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# List to store the output of the scorer2() function for each model
model_output4 = []
for model_name,model in model_dict4.items():
    model_output4.append(scorer4(model_name, model))

# Create a DataFrame from the model output
model_df4 = pd.DataFrame(model_output4, columns=['name','r2','mae'])
# Sort the DataFrame by mean absolute error (mae)
model_df4.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 5       random forest  0.895780  0.444934
# 10            xgboost  0.899333  0.452591
# 6         extra trees  0.893365  0.472016
# 7   gradient boosting  0.883614  0.513560
# 4       decision tree  0.817373  0.569767
# 1                 svr  0.860507  0.598580
# 9                 mlp  0.848005  0.622870
# 0          linear_reg  0.825325  0.651096
# 2               ridge  0.825347  0.651413
# 8            adaboost  0.812397  0.691360
# 3               LASSO -0.000949  1.513728

# %% [markdown]
# **Observation :** With `Target Encoding`,Without using any hyperparameter tuning `RandomForestRegressor`  is giving better performance.
#
# - Target Encoding is giving better performance with `RandomForestRegressor`.

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ## **Hyperparameter Tuning for RandomForestRegressor**
#
# - We will use `GridSearchCV` to find the best hyperparameters for our  `RandomForestRegressor` model.
#
# - We are using same pipeline as we have done in previous case [`Target Encoding`].

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='sklearn.preprocessing._encoders')

# Standard Scaling to Numerical columns
numerical_columns = ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']

# List of columns that need to be encoded
columns_to_encode = ['property_type', 'balcony',  'luxury_category', 'floor_category']

# nominal encoding on nominal columns
nominal_columns =['agePossession','furnishing_type']

# target encoding on sector column
target_encoding_column = ['sector']

# Creating a column transformer for preprocessing
preprocessor5 = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_columns),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),nominal_columns),
        ('target_enc', ce.TargetEncoder(), target_encoding_column)
    ], 
    remainder='passthrough'
)

# Creating a pipeline
pipeline5 = Pipeline([
    ('preprocessor', preprocessor5),
    ('regressor', RandomForestRegressor())
])


# Define the parameter grid for hyperparameter tuning
param_grid = {
    'regressor__n_estimators': [50, 100, 200, 300],  # Number of trees in the forest
    'regressor__max_depth': [None, 10, 20, 30],  # Maximum depth of the tree
    'regressor__max_samples':[0.1, 0.25, 0.5, 1.0],  # Fraction of samples to draw from X to train each base estimator
    'regressor__max_features': ['sqrt', 'log2', None]  # Number of features to consider when looking for the best split
}

# We will train & evaluate the model using K-fold cross-validation
from sklearn.model_selection import GridSearchCV

kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# Perform grid search with cross-validation
search = GridSearchCV(pipeline5, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4) 

# Fit the model to the data
search.fit(X, y_transformed)

# Predict the target values using the best estimator
y_pred = search.best_estimator_.predict(X)



# Calculate the Mean Absolute Error (MAE)
mae5 = mean_absolute_error(np.expm1(y_test),y_pred)

print("Best Parameters : ",search.best_params_)
print("Best R2 - Score : ",search.best_score_)
print("Mean Absolute Error (MAE):", mae5)

# %% [markdown]
# **Observation :** After applying `GridSearchCV`, we are getting better performance.
# - R2 - Score is 0.896
# - MAE is 0.041 crore (4.1 lakhs) ; It means that if a property have actual price is 10 lakh , then predicted price is 14.1  lakh. We are getting  error 4.1 lakhs

# %%
X.dtypes
# Out:
# property_type       object
# sector              object
# bedRoom              int64
# bathroom             int64
# balcony             object
# agePossession       object
# built_up_area      float64
# servant room         int64
# store room           int64
# furnishing_type     object
# luxury_category     object
# floor_category      object
# dtype: object

# %% [markdown]
# **Improvement scope : Select xgboost model and apply hyperparameter tuning [HyperOpt or Bayesian Hyperramater tuning].**

# %% [markdown]
# ---
# ## **Hyperparameter tuning for XGBoost**

# %%
# Creating a pipeline with XGBoost
pipeline6 = Pipeline([
    ('preprocessor', preprocessor5),
    ('regressor', XGBRegressor())  # Change to XGBRegressor
])

# Define the parameter grid for hyperparameter tuning for XGBoost
param_grid = {
    'regressor__n_estimators': [100, 200, 300, 400],
    'regressor__max_depth': [None, 5, 10, 15],
    'regressor__learning_rate': [0.01, 0.1, 0.2],
    'regressor__subsample': [0.5, 0.75, 1.0],
    'regressor__colsample_bytree': [0.5, 0.75, 1.0],
}

# Perform grid search with cross-validation
search = GridSearchCV(pipeline6, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4) 

# Fit the model to the data
search.fit(X, y_transformed)
# Out:
# Fitting 10 folds for each of 432 candidates, totalling 4320 fits
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.696 total time=   0.2s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.702 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.705 total time=   0.2s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.710 total time=   0.3s[CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.712 total time=   0.2s
#
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.697 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.701 total time=   0.3s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.711 total time=   0.3s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.701 total time=   0.3s[CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.691 total time=   0.3s
#
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.707 total time=   0.3s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.686 total time=   0.3s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.704 total time=   0.3s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.708 total time=   0.3s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.706 total time=   0.3s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.708 total time=   0.3s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.698 total time=   0.2s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.710 total time=   0.2s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.689 total time=   0.2s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.697 total time=   0.2s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.713 total time=   0.2s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.709 total time=   0.2s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.699 total time=   0.2s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.707 total time=   0.2s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.710 total time=   0.2s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.711 total time=   0.2s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.690 total time=   0.2s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.701 total time=   0.2s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.713 total time=   0.2s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.700 total time=   0.2s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.845 total time=   0.3s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.845 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.843 total time=   0.3s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.854 total time=   0.3s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.852 total time=   0.3s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.837 total time=   0.4s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.822 total time=   0.3s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.838 total time=   0.3s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.849 total time=   0.3s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.833 total time=   0.3s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.849 total time=   0.3s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.845 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.845 total time=   0.3s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.839 total time=   0.3s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.855 total time=   0.3s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.855 total time=   0.3s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.839 total time=   0.3s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.823 total time=   0.3s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.851 total time=   0.3s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.850 total time=   0.3s[CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.847 total time=   0.3s
#
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.837 total time=   0.3s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.858 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.845 total time=   0.3s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.857 total time=   0.3s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.842 total time=   0.3s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.836 total time=   0.4s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.822 total time=   0.3s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.837 total time=   0.3s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.854 total time=   0.3s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.886 total time=   0.4s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.877 total time=   0.4s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.873 total time=   0.4s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.879 total time=   0.4s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.893 total time=   0.4s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.854 total time=   0.4s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.893 total time=   0.5s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.875 total time=   0.4s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.876 total time=   0.5s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.886 total time=   0.5s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.872 total time=   0.5s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.875 total time=   0.4s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.895 total time=   0.4s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.888 total time=   0.5s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.879 total time=   0.5s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.895 total time=   0.5s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.876 total time=   0.4s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.853 total time=   0.5s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.887 total time=   0.4s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.874 total time=   0.4s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.890 total time=   0.5s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.877 total time=   0.5s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.879 total time=   0.5s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.880 total time=   0.5s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.896 total time=   0.5s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.896 total time=   0.5s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.891 total time=   0.5s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.876 total time=   0.5s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.852 total time=   0.5s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.873 total time=   0.6s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.886 total time=   0.6s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.900 total time=   0.7s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.906 total time=   0.6s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.885 total time=   0.6s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.890 total time=   0.8s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.906 total time=   0.6s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.862 total time=   0.5s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.889 total time=   0.6s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.887 total time=   0.6s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.898 total time=   0.6s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.901 total time=   0.6s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.890 total time=   0.6s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.884 total time=   0.6s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.886 total time=   0.6s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.908 total time=   0.6s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.907 total time=   0.6s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.889 total time=   0.6s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.861 total time=   0.6s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.697 total time=   0.2s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.900 total time=   0.5s[CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.706 total time=   0.2s
#
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.903 total time=   0.6s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.889 total time=   0.6s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.695 total time=   0.2s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.885 total time=   0.5s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.695 total time=   0.2s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.699 total time=   0.2s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.701 total time=   0.2s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.907 total time=   0.5s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.693 total time=   0.2s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.883 total time=   0.6s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.889 total time=   0.6s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.680 total time=   0.2s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.908 total time=   0.6s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.705 total time=   0.2s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.687 total time=   0.2s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.891 total time=   0.6s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.903 total time=   0.6s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.860 total time=   0.6s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.701 total time=   0.2s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=None, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.890 total time=   0.6s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.707 total time=   0.2s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.699 total time=   0.2s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.697 total time=   0.2s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.704 total time=   0.2s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.682 total time=   0.2s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.705 total time=   0.2s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.702 total time=   0.2s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.694 total time=   0.2s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.692 total time=   0.2s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.707 total time=   0.2s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.704 total time=   0.2s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.701 total time=   0.2s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.698 total time=   0.2s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.697 total time=   0.2s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.705 total time=   0.2s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.705 total time=   0.2s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.695 total time=   0.2s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.684 total time=   0.2s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=100, regressor__subsample=1.0;, score=0.709 total time=   0.2s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.841 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.836 total time=   0.2s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.848 total time=   0.2s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.841 total time=   0.3s[CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.834 total time=   0.2s
#
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.850 total time=   0.3s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.835 total time=   0.3s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.816 total time=   0.2s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.845 total time=   0.2s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5;, score=0.828 total time=   0.2s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.843 total time=   0.2s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.835 total time=   0.2s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.841 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.838 total time=   0.3s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.851 total time=   0.2s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.849 total time=   0.2s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.846 total time=   0.2s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.816 total time=   0.3s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.836 total time=   0.3s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.831 total time=   0.2s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.846 total time=   0.2s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.839 total time=   0.2s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.841 total time=   0.3s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.836 total time=   0.3s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.852 total time=   0.3s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.853 total time=   0.2s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.815 total time=   0.2s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.833 total time=   0.2s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.850 total time=   0.3s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.837 total time=   0.3s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.882 total time=   0.4s[CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.873 total time=   0.3s
#
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.871 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.871 total time=   0.3s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.888 total time=   0.3s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.889 total time=   0.4s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.847 total time=   0.4s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.867 total time=   0.3s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.873 total time=   0.4s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.883 total time=   0.3s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.872 total time=   0.3s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.882 total time=   0.4s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.872 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.873 total time=   0.4s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.890 total time=   0.3s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.874 total time=   0.3s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.889 total time=   0.4s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.846 total time=   0.3s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.870 total time=   0.3s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.885 total time=   0.3s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.883 total time=   0.4s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.872 total time=   0.3s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.872 total time=   0.3s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.872 total time=   0.3s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.891 total time=   0.3s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.876 total time=   0.3s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.844 total time=   0.3s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.891 total time=   0.4s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.870 total time=   0.3s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.886 total time=   0.3s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.895 total time=   0.4s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.881 total time=   0.4s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.883 total time=   0.4s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.882 total time=   0.4s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.901 total time=   0.4s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.902 total time=   0.4s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.885 total time=   0.4s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.880 total time=   0.4s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.894 total time=   0.4s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.881 total time=   0.4s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.883 total time=   0.4s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.896 total time=   0.5s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.856 total time=   0.5s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.883 total time=   0.4s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.903 total time=   0.4s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.902 total time=   0.4s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.887 total time=   0.4s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.854 total time=   0.4s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.896 total time=   0.4s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.884 total time=   0.5s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.898 total time=   0.4s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.881 total time=   0.4s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.881 total time=   0.4s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.883 total time=   0.4s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.904 total time=   0.4s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.904 total time=   0.4s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.853 total time=   0.5s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.888 total time=   0.5s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.897 total time=   0.5s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.883 total time=   0.5s
# [CV 2/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.715 total time=   0.6s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.705 total time=   0.7s
# [CV 3/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.705 total time=   0.9s
# [CV 5/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.707 total time=   0.8s
# [CV 7/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.697 total time=   0.8s
# [CV 4/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.697 total time=   1.0s
# [CV 6/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.708 total time=   0.9s
# [CV 8/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.691 total time=   0.9s
# [CV 9/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.709 total time=   0.9s
# [CV 10/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.5;, score=0.692 total time=   0.9s
# [CV 1/10] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=100, regressor__subsample=0.75;, score=0.712 total time=   1.1s
# ...
# [CV 7/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.898 total time=   5.0s
# [CV 3/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.876 total time=   3.3s
# [CV 8/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.856 total time=   4.9s
# [CV 4/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.893 total time=   3.0s
# [CV 10/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.884 total time=   4.8s
# [CV 9/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=0.75;, score=0.903 total time=   5.3s
# [CV 5/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.907 total time=   3.9s
# [CV 6/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.896 total time=   4.0s
# [CV 7/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.898 total time=   3.9s
# [CV 9/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.894 total time=   3.8s
# [CV 10/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.882 total time=   4.2s
# [CV 8/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=200, regressor__subsample=1.0;, score=0.838 total time=   4.5s
# [CV 2/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.881 total time=   6.1s
# [CV 4/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.885 total time=   6.2s
# [CV 5/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.900 total time=   5.9s
# [CV 6/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.894 total time=   6.2s
# [CV 7/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.892 total time=   6.2s
# [CV 8/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.854 total time=   6.5s
# [CV 9/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.892 total time=   6.6s
# [CV 10/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.884 total time=   6.3s
# [CV 3/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.869 total time=   9.7s
# [CV 1/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.5;, score=0.900 total time=   9.9s
# [CV 1/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.915 total time=   3.0s
# [CV 3/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.897 total time=   7.8s[CV 1/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.909 total time=   8.7s
#
# [CV 2/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.884 total time=   3.3s
# [CV 4/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.893 total time=   3.2s
# [CV 3/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.876 total time=   3.3s
# [CV 2/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.878 total time=   8.7s
# [CV 5/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.905 total time=   8.1s
# [CV 9/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.903 total time=   5.7s
# [CV 8/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.856 total time=   6.0s
# [CV 4/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.898 total time=   9.0s
# [CV 6/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.898 total time=   8.6s
# [CV 10/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.884 total time=   5.3s
# [CV 7/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.898 total time=   2.4s
# [CV 7/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=0.75;, score=0.898 total time=   7.9s
# [CV 8/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.838 total time=   3.2s
# [CV 10/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.882 total time=   3.1s
# [CV 6/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.896 total time=   5.4s
# [CV 5/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.907 total time=   5.7s
# [CV 9/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=300, regressor__subsample=1.0;, score=0.894 total time=   4.4s
# [CV 6/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.893 total time=   7.0s
# [CV 5/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.900 total time=   7.4s
# [CV 2/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.881 total time=   8.3s
# [CV 9/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.892 total time=   7.3s
# [CV 1/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.900 total time=   8.7s
# [CV 10/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.886 total time=   7.2s
# [CV 3/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.897 total time=   6.8s
# [CV 2/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.878 total time=   7.1s
# [CV 3/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.870 total time=  10.7s
# [CV 1/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.915 total time=   3.1s
# [CV 2/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.884 total time=   3.2s
# [CV 4/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.884 total time=  11.4s
# [CV 6/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.898 total time=   8.6s
# [CV 1/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.910 total time=  10.2s
# [CV 3/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.876 total time=   3.3s
# [CV 8/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.853 total time=  11.8s
# [CV 7/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.5;, score=0.893 total time=  12.1s
# [CV 4/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.893 total time=   3.5s
# [CV 5/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.905 total time=   9.4s
# [CV 5/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.907 total time=   2.8s
# [CV 4/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.898 total time=   9.9s
# [CV 7/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.898 total time=   6.2s
# [CV 6/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.896 total time=   2.4s
# [CV 7/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.898 total time=   2.2s
# [CV 10/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.883 total time=   5.7s
# [CV 8/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.838 total time=   2.3s
# [CV 9/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.903 total time=   6.2s
# [CV 9/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.894 total time=   1.8s
# [CV 10/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=1.0;, score=0.882 total time=   1.8s
# [CV 8/10] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=15, regressor__n_estimators=400, regressor__subsample=0.75;, score=0.857 total time=   6.4s
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['bedRoom',
#                                                                           'bathroom',
#                                                                           'built_up_area',
#                                                                           'servant '
#                                                                           'room',
#                                                                           'store '
#                                                                           'room']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['property_type',
#                                                                           'b...
#                                                      multi_strategy=None,
#                                                      n_estimators=None,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      random_state=None, ...))]),
#              n_jobs=-1,
#              param_grid={'regressor__colsample_bytree': [0.5, 0.75, 1.0],
#                          'regressor__learning_rate': [0.01, 0.1, 0.2],
#                          'regressor__max_depth': [None, 5, 10, 15],
#                          'regressor__n_estimators': [100, 200, 300, 400],
#                          'regressor__subsample': [0.5, 0.75, 1.0]},
#              scoring='r2', verbose=4)

# %%
# Predict the target values using the best estimator
y_pred = search.best_estimator_.predict(X)

# Calculate the Mean Absolute Error (MAE)
mae6 = mean_absolute_error(np.expm1(y_test),y_pred)

print("***\n\n XGBoost ***")
print("Best Parameters : ", search.best_params_)
print("Best R2 - Score : ", search.best_score_)
print("Mean Absolute Error (MAE):", mae6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 5
#       2 y_pred = search.best_estimator_.predict(X)
#       4 # Calculate the Mean Absolute Error (MAE)
# ----> 5 mae6 = mean_absolute_error(np.expm1(y_test),y_pred)
#       7 print("***\n\n XGBoost ***")
#       8 print("Best Parameters : ", search.best_params_)
#
# File ~/project/real-estate/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/project/real-estate/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:216, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     152 @validate_params(
#     153     {
#     154         "y_true": ["array-like"],
#    (...)
#     162     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     163 ):
#     164     """Mean absolute error regression loss.
#     165
#     166     Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     214     0.85...
#     215     """
# --> 216     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     217         y_true, y_pred, multioutput
#     218     )
#     219     check_consistent_length(y_true, y_pred, sample_weight)
#     220     output_errors = np.average(np.abs(y_pred - y_true), weights=sample_weight, axis=0)
#
# File ~/project/real-estate/venv/lib/python3.10/site-packages/sklearn/metrics/_regression.py:111, in _check_reg_targets(y_true, y_pred, multioutput, dtype, xp)
#      76 """Check that y_true and y_pred belong to the same regression task.
#      77
#      78 Parameters
#    (...)
#     107     correct keyword.
#     108 """
#     109 xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
# --> 111 check_consistent_length(y_true, y_pred)
#     112 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     113 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~/project/real-estate/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [708, 3540]

# %% [markdown]
# **Observation :** After applying `GridSearchCV`on Xgboost , we are getting better performance (R2Score : 0.90, MAE : 0.048 crore) than RandomForestRegressor.
#
# - So We will export the XGBoost model and use it for prediction.

# %% [markdown]
# ---

# %% [markdown]
# ## **Exporting the model**

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='sklearn.preprocessing._encoders')

# Standard Scaling to Numerical columns
numerical_columns = ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']

# List of columns that need to be encoded
columns_to_encode = ['property_type', 'balcony',  'luxury_category', 'floor_category']

# nominal encoding on nominal columns
nominal_columns =['agePossession','furnishing_type']

# target encoding on sector column
target_encoding_column = ['sector']

xgboost_preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_columns),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),nominal_columns),
        ('target_enc', ce.TargetEncoder(), target_encoding_column)
    ], 
    remainder='passthrough'
)

final_pipeline = Pipeline([
    ('preprocessor', xgboost_preprocessor),
    ('regressor', XGBRegressor(n_estimators=500))
])

final_pipeline.fit(X,y_transformed)


# Save the trained pipeline to a file
with open('../models/xgboost_pipeline.pkl', 'wb') as file:
    pickle.dump(final_pipeline, file)

# Save the DataFrame to a file for future use
with open('../models/xgboost_df.pkl', 'wb') as file:
    pickle.dump(X, file)

# %% [markdown]
# ---
# ## **Trying out the predictions**

# %%
X.columns

# %%
X.iloc[0].values

# %%
data = [['house', 'sector 102', 4, 3, '3+', 'New Property', 2750, 0, 0, 'unfurnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
       'agePossession', 'built_up_area', 'servant room', 'store room',
       'furnishing_type', 'luxury_category', 'floor_category']

# Convert to DataFrame
one_df = pd.DataFrame(data, columns=columns)

one_df

# %%
np.expm1(pipeline.predict(one_df))

# %%
X.dtypes

# %%
sorted(X['sector'].unique().tolist())

# %% [markdown]
# **END**
#
# ---
