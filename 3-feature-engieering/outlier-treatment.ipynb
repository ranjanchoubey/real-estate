# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/clean-data/flats-house-cleaned-v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat  emaar mgf palm hills   sector 77   1.50         12744.0
# 1          flat       raheja vedaanta  sector 108   0.85          4637.0
# 2          flat     511 sarahah tower   sector 12   0.60          8333.0
# 3          flat         laxmi pareena  sector 99a   0.30          6666.0
# 4          flat  emaar gurgaon greens  sector 102   1.55          9393.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1177.0  Super Built up area 1450(134.71 sq.m.)Carpet a...        3
# 1  1833.0  Super Built up area 1833(170.29 sq.m.)Built Up...        3
# 2   720.0                     Carpet area: 720 (66.89 sq.m.)        2
# 3   450.0                     Carpet area: 450 (41.81 sq.m.)        2
# 4  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# /tmp/ipykernel_2352/2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 2039         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 3327         house                                        independent
# 2482         house                                        independent
# 3530         house                                     dlf city plots
# 659          house                                   suncity township
# 3506         house                             emaar the palm springs
# 3677         house                                        independent
# 1306         house                                 vipul tatvam villa
# 2044         house                             luxury dlf city floors
# 1118         house                                        independent
# 2545         house                                     dlf city plots
# 830          house                                 vipul tatvam villa
# ...

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as we

# %% [markdown]
# ### Price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# /tmp/ipykernel_2352/2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# /tmp/ipykernel_2352/205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# /tmp/ipykernel_2352/3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# /tmp/ipykernel_2352/2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 270           flat                unitech vistas        sector 70   9.00
# 589          house                   independent        sector 26  14.75
# 641          house                unitech escape        sector 50  10.80
# 661          house                           nul        sector 28  12.50
# 684          house            emaar mgf marbella        sector 66  18.00
# 1435         house                  malibu towne        sector 47   8.50
# 2482         house                   independent        sector 26  26.00
# 2910         house                   independent        sector 25  16.00
# 3217         house            cloudnine cottages  sohna road road   5.50
# 3471         house  project housing board colony        sector 31   8.00
# 3506         house        emaar the palm springs        sector 54  24.00
# 3527         house        emaar the palm springs        sector 54  14.00
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### Area

# %%
sns.distplot(df['area'])
# Out:
# /tmp/ipykernel_2352/91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
# rows where 'area' is greater than 10000 and returns the shape of the resulting dataframe.
df[df['area'] > 10000].shape
# Out:
# (25, 23)

# %%
df = df[df['area'] < 10000]

# %%
df.shape
# Out:
# (3618, 23)

# %%
sns.distplot(df['area'])
# Out:
# /tmp/ipykernel_2352/91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count    3618.000000
# mean     1931.404091
# std      1153.703547
# min       145.000000
# 25%      1260.000000
# 50%      1745.000000
# 75%      2320.000000
# max      9001.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 10000].sort_values('area', ascending=False)
# The result is empty because the condition `df['area'] > 10000` is not met for any row in the dataframe after the previous operations.
# This is likely due to the data cleaning and outlier removal steps performed earlier in the notebook.
# To verify this, you can check the maximum value of 'area' in the dataframe to ensure it does not exceed 10000.
max_area = df['area'].max()
print(f"Maximum area value in the dataframe: {max_area}")

# 818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471
# Out:
# Maximum area value in the dataframe: 9001.0

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# 818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %%
df['area'].isin([818, 1796, 1123, 2, 115, 3649, 2503, 1471])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3798    False
# 3799    False
# 3800    False
# 3801    False
# 3802    False
# Name: area, Length: 3618, dtype: bool

# %%
df.drop(index=df.index[df['area'].isin([818, 1796, 1123, 2, 115, 3649, 2503, 1471])], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %% [markdown]
# # manually verified the data and corrected the area

# %%
df.loc[48,'area'] = 115*9
df.loc[300,'area'] = 7250
df.loc[2666,'area'] = 5800
df.loc[1358,'area'] = 2660
df.loc[3195,'area'] = 2850
df.loc[2131,'area'] = 1812
df.loc[3088,'area'] = 2160
df.loc[3444,'area'] = 1175

# %%
df.shape
# Out:
# (3617, 23)

# %%
sns.distplot(df['area'], kde =True)
# Out:
# /tmp/ipykernel_2352/1897191209.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'], kde =True)
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count    3617.000000
# mean     1934.082942
# std      1158.825547
# min       145.000000
# 25%      1260.000000
# 50%      1745.000000
# 75%      2321.000000
# max      9001.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# /tmp/ipykernel_2352/1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3617.000000
# mean        3.323472
# std         1.818776
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society         sector  price  \
# 501          house                  independent      sector 54   5.00
# 1948         house                  independent      sector 43   4.50
# 2958         house                  independent     sector 17a   3.93
# 2162         house                  independent     sector 17a   3.87
# 2746         house                private house      sector 55   7.05
# 3529         house                  independent      sector 54   5.50
# 3120         house                  independent      sector 40  12.00
# 2923         house                  independent  shivaji nagar   4.50
# 2545         house               dlf city plots      sector 26  20.00
# 288          house                  independent      sector 55   9.19
# 2044         house       luxury dlf city floors      sector 26  20.00
# 3105         house                  independent      sector 56  12.39
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3572, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# /tmp/ipykernel_2352/1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3572.000000
# mean        3.192889
# std         1.375680
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# /tmp/ipykernel_2352/2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 2116         house  adani brahma samsara  sector 60  18.02         28200.0
# 774          house           independent  sector 39   7.00         10000.0
# 3165         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 2116  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 774   7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 3165  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 2116        12      3+       3.0  North-East  Relatively New
# 774         11      3+       4.0  South-East  Relatively New
# 3165        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat  emaar mgf palm hills   sector 77   1.50         12744.0
# 1          flat       raheja vedaanta  sector 108   0.85          4637.0
# 2          flat     511 sarahah tower   sector 12   0.60          8333.0
# 3          flat         laxmi pareena  sector 99a   0.30          6666.0
# 4          flat  emaar gurgaon greens  sector 102   1.55          9393.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1177.0  Super Built up area 1450(134.71 sq.m.)Carpet a...        3
# 1  1833.0  Super Built up area 1833(170.29 sq.m.)Built Up...        3
# 2   720.0                     Carpet area: 720 (66.89 sq.m.)        2
# 3   450.0                     Carpet area: 450 (41.81 sq.m.)        2
# 4  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# /tmp/ipykernel_2352/4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count    1874.000000
# mean     1920.928789
# std       741.242807
# min        89.000000
# 25%      1479.250000
# 50%      1828.000000
# 75%      2215.000000
# max      6926.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society     sector  price  \
# 2288          flat  bestech park view grand spa  sector 81    4.7
#
#       price_per_sqft    area                            areaWithType  bedRoom  \
# 2288          6786.0  6926.0  Super Built up area 6926(643.45 sq.m.)        4
#
#       bathroom balcony  floorNum facing   agePossession  super_built_up_area  \
# 2288         4      3+      19.0  North  Relatively New               6926.0
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 2288            NaN          NaN           0             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 2288           0       0                2           140

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# /tmp/ipykernel_2352/3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# /tmp/ipykernel_2352/3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %%
df.loc[2131,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat  emaar mgf palm hills   sector 77   1.50         12744.0
# 1          flat       raheja vedaanta  sector 108   0.85          4637.0
# 2          flat     511 sarahah tower   sector 12   0.60          8333.0
# 3          flat         laxmi pareena  sector 99a   0.30          6666.0
# 4          flat  emaar gurgaon greens  sector 102   1.55          9393.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1177.0  Super Built up area 1450(134.71 sq.m.)Carpet a...        3
# 1  1833.0  Super Built up area 1833(170.29 sq.m.)Built Up...        3
# 2   720.0                     Carpet area: 720 (66.89 sq.m.)        2
# 3   450.0                     Carpet area: 450 (41.81 sq.m.)        2
# 4  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['luxury_score'])
# Out:
# /tmp/ipykernel_2352/3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3572, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat  emaar mgf palm hills   sector 77   1.50         12744.0
# 1          flat       raheja vedaanta  sector 108   0.85          4637.0
# 2          flat     511 sarahah tower   sector 12   0.60          8333.0
# 3          flat         laxmi pareena  sector 99a   0.30          6667.0
# 4          flat  emaar gurgaon greens  sector 102   1.55          9394.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1177.0  Super Built up area 1450(134.71 sq.m.)Carpet a...        3
# 1  1833.0  Super Built up area 1833(170.29 sq.m.)Built Up...        3
# 2   720.0                     Carpet area: 720 (66.89 sq.m.)        2
# 3   450.0                     Carpet area: 450 (41.81 sq.m.)        2
# 4  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# /tmp/ipykernel_2352/2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 118          house                   independent   sector 28   12.0
# 202          house                   independent   sector 26   19.0
# 266          house                   independent   sector 55    5.0
# 827          house                dlf city plots   sector 26   19.0
# 1118         house                   independent   sector 26   20.0
# 1427         house                   independent   sector 43    9.5
# 2187         house                   independent  sector 105    9.9
# 3444         house           ireo victory valley   sector 67    8.0
# 3641         house                   independent   sector 25   13.0
# 3760         house  sushant lok 1 builder floors   sector 43   13.0
#
#       price_per_sqft    area  \
# 118          42194.0  2844.0
# 202          42222.0  4500.0
# 266          44444.0  1125.0
# 827          42054.0  4518.0
# 1118         44444.0  4500.0
# 1427         42222.0  2250.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.02)
# Out:
# 185.20000000000002

# %%
df[(df['area']/df['bedRoom'])<185].sample(5)
# Out:
#      property_type         society      sector  price  price_per_sqft    area  \
# 1895         house     independent    sector 4    1.1         11111.0   990.0
# 305          house   sector 38 rwa   sector 38    4.3         28782.0  1494.0
# 683          house     independent   sector 11    0.9         10000.0   900.0
# 2643         house  sector 57 huda   sector 57    3.8         26063.0  1458.0
# 555          house     independent  sector 104    0.6          5128.0  1170.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1895                   Built Up area: 990 (91.97 sq.m.)        6         4
# 305   Plot area 166(138.8 sq.m.)Built Up area: 165 s...        9         9
# 683                          Plot area 900(83.61 sq.m.)        7         4
# 2643  Plot area 162(135.45 sq.m.)Built Up area: 162 ...        8         8
# 555                          Plot area 130(108.7 sq.m.)        7         3
#
# ...

# %%
import seaborn as sns

sns.lmplot(data=df, x='area', y='bedRoom')

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
(df[df['area_room_ratio']<185])['bedRoom'].value_counts()
# Out:
# bedRoom
# 3    8
# 2    5
# 4    3
# 5    3
# 6    2
# 8    1
# 9    1
# Name: count, dtype: int64

# %%
df = df[df['area_room_ratio']>100]

# %%
outliers_df = df[(df['area_room_ratio']<185)&(df['bedRoom']>3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# /tmp/ipykernel_2352/3450078040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']
# Out:
# /tmp/ipykernel_2352/465686754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio']<185)& (df['bedRoom']>4)]
# Out:
#      property_type               society            sector  price  \
# 1000         house           independent       imt manesar   0.80
# 1132         house  bhim nagar, sector 6        bhim nagar   0.85
# 1927         house           independent     garhi harsaru   0.32
# 2509         house           independent          sector 2   0.98
# 2722         house           independent  sector 3 phase 2   0.85
# 2739         house           independent        sector 105   1.10
# 3128         house           independent         sector 12   0.65
#
#       price_per_sqft    area                      areaWithType  bedRoom  \
# 1000          6667.0  1200.0      Plot area 1200(111.48 sq.m.)        8
# 1132         14096.0   603.0          Plot area 67(6.22 sq.m.)        5
# 1927          5664.0   565.0  Built Up area: 565 (52.49 sq.m.)        5
# 2509          9074.0  1080.0   Carpet area: 120 (100.34 sq.m.)        9
# 2722          9444.0   900.0    Carpet area: 900 (83.61 sq.m.)        5
# ...

# %%
df[(df['area_room_ratio']<185)& (df['bedRoom']>4)].shape
# Out:
# (7, 24)

# %%
df.shape
# Out:
# (3552, 24)

# %%
df =df[~((df['area_room_ratio']<185)& (df['bedRoom']>4))]

# %%
import seaborn as sns

sns.lmplot(data=df, x='area', y='bedRoom')

# %%
df.shape
# Out:
# (3545, 24)

# %%
df.to_csv('./gurgaon_properties_outlier_treated.csv')
