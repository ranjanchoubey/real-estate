# %% [markdown]
# ## **Recommender system for real estate data**
#
#  We have planned to build 3 recommendation systems.
# 1. Based on `Facilities`
# 2. Based on `Price`
# 3. Based on `Location`
#
# We will assign weight of these three recommendation systems manually respectively and use hybrid approach (combination of all three) to get the recommendations.

# %%
# importing the required libraries
import numpy as np
import pandas as pd
import re
import json
import ast

# %% [markdown]
# ## **Load the data**

# %%
input_path = '../data/scrap-data/appartments.csv'
df = pd.read_csv(input_path)
print("shape of  the dataframe:",df.shape)
df.head()
# Out:
# shape of  the dataframe: (247, 7)
#                   PropertyName  \
# 0           Smartworld One DXP
# 1                    M3M Crown
# 2  Adani Brahma Samsara Vilasa
# 3                   Sobha City
# 4     Signature Global City 93
#
#                                      PropertySubName  \
# 0       2, 3, 4 BHK Apartment in Sector 113, Gurgaon
# 1          3, 4 BHK Apartment in Sector 111, Gurgaon
# 2  Land, 3, 4 BHK Independent Floor in Sector 63,...
# 3       2, 3, 4 BHK Apartment in Sector 108, Gurgaon
# 4    2, 3 BHK Independent Floor in Sector 93 Gurgaon
#
#                                      NearbyLocations  \
# 0  ['Bajghera Road', 'Palam Vihar Halt', 'DPSG Pa...
# 1  ['DPSG Palam Vihar Gurugram', 'The NorthCap Un...
# 2  ['AIPL Business Club Sector 62', 'Heritage Xpe...
# 3  ['The Shikshiyan School', 'WTC Plaza', 'Luxus ...
# 4  ['Pranavananda Int. School', 'DLF Site central...
#
#                                   LocationAdvantages  \
# 0  {'Bajghera Road': '800 Meter', 'Palam Vihar Ha...
# 1  {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The N...
# 2  {'AIPL Business Club Sector 62': '2.7 Km', 'He...
# 3  {'The Shikshiyan School': '2.9 KM', 'WTC Plaza...
# 4  {'Pranavananda Int. School': '450 m', 'DLF Sit...
#
#                                                 Link  \
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
#                                         PriceDetails  \
# 0  {'2 BHK': {'building_type': 'Apartment', 'area...
# 1  {'3 BHK': {'building_type': 'Apartment', 'area...
# 2  {'3 BHK': {'building_type': 'Independent Floor...
# 3  {'2 BHK': {'building_type': 'Apartment', 'area...
# 4  {'2 BHK': {'building_type': 'Independent Floor...
#
#                                        TopFacilities
# 0  ['Swimming Pool', 'Salon', 'Restaurant', 'Spa'...
# 1  ['Bowling Alley', 'Mini Theatre', 'Manicured G...
# 2  ['Terrace Garden', 'Gazebo', 'Fountain', 'Amph...
# 3  ['Swimming Pool', 'Volley Ball Court', 'Aerobi...
# 4  ['Mini Theatre', 'Doctor on Call', 'Concierge ...

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# ### 1. removing garbage rows

# %%
# we found that there is a garbage row in the dataframe
df.iloc[22]
# Out:
# PropertyName                PropertyName
# PropertySubName          PropertySubName
# NearbyLocations          NearbyLocations
# LocationAdvantages    LocationAdvantages
# Link                                Link
# PriceDetails                PriceDetails
# TopFacilities              TopFacilities
# Name: 22, dtype: object

# %%
# removing the garbage row
df.drop(22,inplace=True)

print("shape of  the dataframe:",df.shape)
df.head()
# Out:
# shape of  the dataframe: (246, 7)
#                   PropertyName  \
# 0           Smartworld One DXP
# 1                    M3M Crown
# 2  Adani Brahma Samsara Vilasa
# 3                   Sobha City
# 4     Signature Global City 93
#
#                                      PropertySubName  \
# 0       2, 3, 4 BHK Apartment in Sector 113, Gurgaon
# 1          3, 4 BHK Apartment in Sector 111, Gurgaon
# 2  Land, 3, 4 BHK Independent Floor in Sector 63,...
# 3       2, 3, 4 BHK Apartment in Sector 108, Gurgaon
# 4    2, 3 BHK Independent Floor in Sector 93 Gurgaon
#
#                                      NearbyLocations  \
# 0  ['Bajghera Road', 'Palam Vihar Halt', 'DPSG Pa...
# 1  ['DPSG Palam Vihar Gurugram', 'The NorthCap Un...
# 2  ['AIPL Business Club Sector 62', 'Heritage Xpe...
# 3  ['The Shikshiyan School', 'WTC Plaza', 'Luxus ...
# 4  ['Pranavananda Int. School', 'DLF Site central...
#
#                                   LocationAdvantages  \
# 0  {'Bajghera Road': '800 Meter', 'Palam Vihar Ha...
# 1  {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The N...
# 2  {'AIPL Business Club Sector 62': '2.7 Km', 'He...
# 3  {'The Shikshiyan School': '2.9 KM', 'WTC Plaza...
# 4  {'Pranavananda Int. School': '450 m', 'DLF Sit...
#
#                                                 Link  \
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
#                                         PriceDetails  \
# 0  {'2 BHK': {'building_type': 'Apartment', 'area...
# 1  {'3 BHK': {'building_type': 'Apartment', 'area...
# 2  {'3 BHK': {'building_type': 'Independent Floor...
# 3  {'2 BHK': {'building_type': 'Apartment', 'area...
# 4  {'2 BHK': {'building_type': 'Independent Floor...
#
#                                        TopFacilities
# 0  ['Swimming Pool', 'Salon', 'Restaurant', 'Spa'...
# 1  ['Bowling Alley', 'Mini Theatre', 'Manicured G...
# 2  ['Terrace Garden', 'Gazebo', 'Fountain', 'Amph...
# 3  ['Swimming Pool', 'Volley Ball Court', 'Aerobi...
# 4  ['Mini Theatre', 'Doctor on Call', 'Concierge ...

# %% [markdown]
# Observation :
# -  `NearbyLocations` is subset of `LocationAdvantages` column .
# - `PropertySubName` is subset of  `PriceDetails` column.
# - `Link` column can be used to get the details of the property.
#
# So these we are dropping the subset columns.

# %% [markdown]
# ### 2. Dropping the subset columns

# %%
df.drop(columns=['NearbyLocations','PropertySubName'],inplace=True)
df.head()
# Out:
#                   PropertyName  \
# 0           Smartworld One DXP
# 1                    M3M Crown
# 2  Adani Brahma Samsara Vilasa
# 3                   Sobha City
# 4     Signature Global City 93
#
#                                   LocationAdvantages  \
# 0  {'Bajghera Road': '800 Meter', 'Palam Vihar Ha...
# 1  {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The N...
# 2  {'AIPL Business Club Sector 62': '2.7 Km', 'He...
# 3  {'The Shikshiyan School': '2.9 KM', 'WTC Plaza...
# 4  {'Pranavananda Int. School': '450 m', 'DLF Sit...
#
#                                                 Link  \
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
#                                         PriceDetails  \
# 0  {'2 BHK': {'building_type': 'Apartment', 'area...
# 1  {'3 BHK': {'building_type': 'Apartment', 'area...
# 2  {'3 BHK': {'building_type': 'Independent Floor...
# 3  {'2 BHK': {'building_type': 'Apartment', 'area...
# 4  {'2 BHK': {'building_type': 'Independent Floor...
#
#                                        TopFacilities
# 0  ['Swimming Pool', 'Salon', 'Restaurant', 'Spa'...
# 1  ['Bowling Alley', 'Mini Theatre', 'Manicured G...
# 2  ['Terrace Garden', 'Gazebo', 'Fountain', 'Amph...
# 3  ['Swimming Pool', 'Volley Ball Court', 'Aerobi...
# 4  ['Mini Theatre', 'Doctor on Call', 'Concierge ...

# %% [markdown]
# ---

# %% [markdown]
# ## **Recommendation System 1 : Based on `Facilities`**

# %% [markdown]
# #### Step1 : Pre-processing the `TopFacilities` column
#
#  - converting the string representation of the list into an actual list
#  - joins the list of facilities into a single string for each property

# %%
df[['PropertyName','TopFacilities']].head()
# Out:
#                   PropertyName  \
# 0           Smartworld One DXP
# 1                    M3M Crown
# 2  Adani Brahma Samsara Vilasa
# 3                   Sobha City
# 4     Signature Global City 93
#
#                                        TopFacilities
# 0  ['Swimming Pool', 'Salon', 'Restaurant', 'Spa'...
# 1  ['Bowling Alley', 'Mini Theatre', 'Manicured G...
# 2  ['Terrace Garden', 'Gazebo', 'Fountain', 'Amph...
# 3  ['Swimming Pool', 'Volley Ball Court', 'Aerobi...
# 4  ['Mini Theatre', 'Doctor on Call', 'Concierge ...

# %%
# This function extracts all the strings enclosed in single quotes from the input string
def extract_list(s):
    return re.findall(r"'(.*?)'", s)

# Applying the extract_list function to the 'TopFacilities' column to convert the string representation of the list into an actual list
df['Facilities'] = df['TopFacilities'].apply(extract_list)

# joins the list of facilities into a single string for each property
df['Facilities'] = df['Facilities'].apply(' '.join)


df[['PropertyName','Facilities']].head()
# Out:
#                   PropertyName  \
# 0           Smartworld One DXP
# 1                    M3M Crown
# 2  Adani Brahma Samsara Vilasa
# 3                   Sobha City
# 4     Signature Global City 93
#
#                                           Facilities
# 0  Swimming Pool Salon Restaurant Spa Cafeteria S...
# 1  Bowling Alley Mini Theatre Manicured Garden Sw...
# 2  Terrace Garden Gazebo Fountain Amphitheatre Pa...
# 3  Swimming Pool Volley Ball Court Aerobics Centr...
# 4  Mini Theatre Doctor on Call Concierge Service ...

# %% [markdown]
# ### Step2 : Vectorizing the `Facilities` column

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the TfidfVectorizer with stop words set to 'english' and ngram range of (1, 2)
tfidf_vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1, 2))

tfidf_matrix = tfidf_vectorizer.fit_transform(df['Facilities'])

# %%
# tfidf_matrix.toarray()[0]

# %% [markdown]
# #### Step3 : Computing the cosine similarity matrix

# %%
from sklearn.metrics.pairwise import cosine_similarity

facilities_cosine_similarity = cosine_similarity(tfidf_matrix, tfidf_matrix)

print("shape of the facilities cosine similarity matrix:",facilities_cosine_similarity.shape)
facilities_cosine_similarity
# Out:
# shape of the facilities cosine similarity matrix: (246, 246)
# array([[1.        , 0.01095159, 0.        , ..., 0.01183329, 0.08656385,
#         0.0110727 ],
#        [0.01095159, 1.        , 0.01982121, ..., 0.11904241, 0.01555534,
#         0.00963852],
#        [0.        , 0.01982121, 1.        , ..., 0.07020502, 0.03820314,
#         0.01962826],
#        ...,
#        [0.01183329, 0.11904241, 0.07020502, ..., 1.        , 0.09825738,
#         0.03255851],
#        [0.08656385, 0.01555534, 0.03820314, ..., 0.09825738, 1.        ,
#         0.06257614],
#        [0.0110727 , 0.00963852, 0.01962826, ..., 0.03255851, 0.06257614,
#         1.        ]])

# %% [markdown]
# **Observation** :
# - The diagonal elements of the matrix are 1 as each property is most similar to itself.
# - The off-diagonal elements are the cosine similarity between the properties based on the facilities.
# - The higher the cosine similarity, the more similar the properties are.

# %% [markdown]
# #### Step 4 : Get the recommendations for a property based on facilities

# %%
def recommend_properties(property_name, cosine_similarity_matrix):
    # Get the index of the property that matches the name
    idx = df.index[df['PropertyName'] == property_name].tolist()[0]

    # Get the pairwise similarity scores with that property
    sim_scores = list(enumerate(cosine_similarity_matrix[idx]))

    # Sort the properties based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar properties
    sim_scores = sim_scores[1:6]

    # Get the property indices
    property_indices = [i[0] for i in sim_scores]
    
    recommendations_df = pd.DataFrame({
        'PropertyName': df['PropertyName'].iloc[property_indices],
        'SimilarityScore': sim_scores
    })

    recommendations_df.sort_values(by='SimilarityScore',ascending=False,inplace=True)
    
    # Return the top 10 most similar properties
    return recommendations_df

# %%
# get the recommendations for a property based on facilities
recommend_properties("DLF The Arbour",facilities_cosine_similarity)
# Out:
#            PropertyName            SimilarityScore
# 217         Yashika 104  (216, 0.4199606322926784)
# 154       India Rashtra   (153, 0.398954234680194)
# 93       JMS The Nation   (92, 0.4166584649363288)
# 64      Ace Palm Floors   (63, 0.4529382062441955)
# 0    Smartworld One DXP   (0, 0.38885046199432893)

# %% [markdown]
# - We will use this function to recommend the properties based on the `facilities`.

# %% [markdown]
# ----

# %% [markdown]
# ## **Recommendation System 2 : Based on `Price`**

# %% [markdown]
# #### Step1 : Pre-processing the `PriceDetails` column
#
# **Purpose:**
# - The preprocessing step transforms raw PriceDetails data into a structured format, making it suitable for further analysis and building recommendation systems.
#
# - Extracted features include building types, area ranges, and price ranges for different property configurations, which are essential for making accurate and relevant property recommendations.

# %%
df[['PropertyName','PriceDetails']]
# Out:
#                     PropertyName  \
# 0             Smartworld One DXP
# 1                      M3M Crown
# 2    Adani Brahma Samsara Vilasa
# 3                     Sobha City
# 4       Signature Global City 93
# ..                           ...
# 242         DLF Princeton Estate
# 243        Pyramid Urban Homes 2
# 244          Satya The Hermitage
# 245                  BPTP Spacio
# 246             SS The Coralwood
#
#                                           PriceDetails
# 0    {'2 BHK': {'building_type': 'Apartment', 'area...
# 1    {'3 BHK': {'building_type': 'Apartment', 'area...
# 2    {'3 BHK': {'building_type': 'Independent Floor...
# 3    {'2 BHK': {'building_type': 'Apartment', 'area...
# 4    {'2 BHK': {'building_type': 'Independent Floor...
# ..                                                 ...
# 242  {'2 BHK': {'building_type': 'Apartment', 'area...
# 243  {'1 BHK': {'building_type': 'Apartment', 'area...
# 244  {'2 BHK': {'building_type': 'Apartment', 'area...
# 245  {'2 BHK': {'building_type': 'Apartment', 'area...
# 246  {'2 BHK': {'building_type': 'Apartment', 'area...
#
# [246 rows x 2 columns]

# %% [markdown]
# **Parsing and Extracting Features:**
# - A function refined_parse_modified() is defined to parse the PriceDetails column, which contains property details in a string format.
#
# - The function converts the string into a dictionary and extracts key features such as building type, area, and price details for various property configurations (e.g., '1 BHK', '2 BHK').
#
# - It handles ranges in area and price details, converting them into numerical values for easier analysis.
#
# **Generating a New DataFrame:**
# - The code iterates over each row in the original DataFrame and applies the parsing function to the PriceDetails column.
#
# - For each row, it constructs a new row with the extracted features and appends it to a list.
#
# - A new DataFrame is created from this list, with PropertyName set as the index.

# %%
# Function to parse and extract the required features from the PriceDetails column
def refined_parse_modified(detail_str):
    try:
        details = json.loads(detail_str.replace("'", "\""))
    except:
        return {}

    extracted = {}
    for bhk, detail in details.items():
        # Extract building type
        extracted[f'building type_{bhk}'] = detail.get('building_type')

        # Parsing area details
        area = detail.get('area', '')
        area_parts = area.split('-')
        if len(area_parts) == 1:
            try:
                value = float(area_parts[0].replace(',', '').replace(' sq.ft.', '').strip())
                extracted[f'area low {bhk}'] = value
                extracted[f'area high {bhk}'] = value
            except:
                extracted[f'area low {bhk}'] = None
                extracted[f'area high {bhk}'] = None
        elif len(area_parts) == 2:
            try:
                extracted[f'area low {bhk}'] = float(area_parts[0].replace(',', '').replace(' sq.ft.', '').strip())
                extracted[f'area high {bhk}'] = float(area_parts[1].replace(',', '').replace(' sq.ft.', '').strip())
            except:
                extracted[f'area low {bhk}'] = None
                extracted[f'area high {bhk}'] = None

        # Parsing price details
        price_range = detail.get('price-range', '')
        price_parts = price_range.split('-')
        if len(price_parts) == 2:
            try:
                extracted[f'price low {bhk}'] = float(price_parts[0].replace('₹', '').replace(' Cr', '').replace(' L', '').strip())
                extracted[f'price high {bhk}'] = float(price_parts[1].replace('₹', '').replace(' Cr', '').replace(' L', '').strip())
                if 'L' in price_parts[0]:
                    extracted[f'price low {bhk}'] /= 100
                if 'L' in price_parts[1]:
                    extracted[f'price high {bhk}'] /= 100
            except:
                extracted[f'price low {bhk}'] = None
                extracted[f'price high {bhk}'] = None

    return extracted

# %%
# Apply the refined parsing and generate the new DataFrame structure
data_refined = []

for _, row in df.iterrows():
    features = refined_parse_modified(row['PriceDetails'])
    
    # Construct a new row for the transformed dataframe
    new_row = {'PropertyName': row['PropertyName']}
    
    # Populate the new row with extracted features
    for config in ['1 BHK', '2 BHK', '3 BHK', '4 BHK', '5 BHK', '6 BHK', '1 RK', 'Land']:
        new_row[f'building type_{config}'] = features.get(f'building type_{config}')
        new_row[f'area low {config}'] = features.get(f'area low {config}')
        new_row[f'area high {config}'] = features.get(f'area high {config}')
        new_row[f'price low {config}'] = features.get(f'price low {config}')
        new_row[f'price high {config}'] = features.get(f'price high {config}')
    
    data_refined.append(new_row)

df_refined = pd.DataFrame(data_refined).set_index('PropertyName')

# %%
df_refined.sample(5)
# Out:
#                        building type_1 BHK  area low 1 BHK  area high 1 BHK  \
# PropertyName
# Central Park Resorts                  None             NaN              NaN
# Pareena Mi Casa                       None             NaN              NaN
# Krrish Florence Estate                None             NaN              NaN
# M3M Capital                           None             NaN              NaN
# Emaar Palm Gardens                    None             NaN              NaN
#
#                         price low 1 BHK  price high 1 BHK building type_2 BHK  \
# PropertyName
# Central Park Resorts                NaN               NaN           Apartment
# Pareena Mi Casa                     NaN               NaN           Apartment
# Krrish Florence Estate              NaN               NaN                None
# M3M Capital                         NaN               NaN           Apartment
# Emaar Palm Gardens                  NaN               NaN                None
#
#                         area low 2 BHK  area high 2 BHK  price low 2 BHK  \
# PropertyName
# Central Park Resorts            1255.0           1676.0             2.75
# Pareena Mi Casa                  865.0           1245.0            68.33
# Krrish Florence Estate             NaN              NaN              NaN
# M3M Capital                     1300.0           1330.0             1.30
# Emaar Palm Gardens                 NaN              NaN              NaN
#
#                         price high 2 BHK  ... building type_1 RK  \
# PropertyName                              ...
# Central Park Resorts              5.4800  ...               None
# Pareena Mi Casa                   0.9836  ...               None
# Krrish Florence Estate               NaN  ...               None
# M3M Capital                       1.5600  ...               None
# Emaar Palm Gardens                   NaN  ...               None
#
#                         area low 1 RK  area high 1 RK  price low 1 RK  \
# PropertyName
# Central Park Resorts              NaN             NaN             NaN
# Pareena Mi Casa                   NaN             NaN             NaN
# Krrish Florence Estate            NaN             NaN             NaN
# M3M Capital                       NaN             NaN             NaN
# Emaar Palm Gardens                NaN             NaN             NaN
#
#                         price high 1 RK building type_Land  area low Land  \
# PropertyName
# Central Park Resorts                NaN               None            NaN
# Pareena Mi Casa                     NaN               None            NaN
# Krrish Florence Estate              NaN               None            NaN
# M3M Capital                         NaN               None            NaN
# Emaar Palm Gardens                  NaN               None            NaN
#
#                         area high Land  price low Land  price high Land
# PropertyName
# Central Park Resorts               NaN             NaN              NaN
# Pareena Mi Casa                    NaN             NaN              NaN
# Krrish Florence Estate             NaN             NaN              NaN
# M3M Capital                        NaN             NaN              NaN
# Emaar Palm Gardens                 NaN             NaN              NaN
#
# [5 rows x 40 columns]

# %%
df_refined[['building type_Land']].sample(5)
# Out:
#                        building type_Land
# PropertyName
# Whiteland The Aspen                  None
# DLF The Summit                       None
# Puri Diplomatic Greens               None
# Signature The Roselia                None
# Mahindra Luminare                    None

# %%
# Replace empty strings in 'building type_Land' column with 'Land'
df_refined['building type_Land'] = df_refined['building type_Land'].replace({'':'Land'})

# %%
df_refined.head(2)
# Out:
#                    building type_1 BHK  area low 1 BHK  area high 1 BHK  \
# PropertyName
# Smartworld One DXP                None             NaN              NaN
# M3M Crown                         None             NaN              NaN
#
#                     price low 1 BHK  price high 1 BHK building type_2 BHK  \
# PropertyName
# Smartworld One DXP              NaN               NaN           Apartment
# M3M Crown                       NaN               NaN                None
#
#                     area low 2 BHK  area high 2 BHK  price low 2 BHK  \
# PropertyName
# Smartworld One DXP          1370.0           1370.0              2.0
# M3M Crown                      NaN              NaN              NaN
#
#                     price high 2 BHK  ... building type_1 RK  area low 1 RK  \
# PropertyName                          ...
# Smartworld One DXP               2.4  ...               None            NaN
# M3M Crown                        NaN  ...               None            NaN
#
#                     area high 1 RK  price low 1 RK  price high 1 RK  \
# PropertyName
# Smartworld One DXP             NaN             NaN              NaN
# M3M Crown                      NaN             NaN              NaN
#
#                    building type_Land  area low Land  area high Land  \
# PropertyName
# Smartworld One DXP               None            NaN             NaN
# M3M Crown                        None            NaN             NaN
#
#                     price low Land  price high Land
# PropertyName
# Smartworld One DXP             NaN              NaN
# M3M Crown                      NaN              NaN
#
# [2 rows x 40 columns]

# %% [markdown]
# **Observation:**
#
# - Some of the columns are categorical variables.
# - We need to convert these categorical variables into numerical variables.[one hot encoding]
# - We can use the `pd.get_dummies()` function to convert the categorical variables into numerical variables.

# %%
categorical_columns = df_refined.select_dtypes(include=['object']).columns.tolist()
print("Categorical Columns:",categorical_columns)

# One Hot Encoding
ohe_df = pd.get_dummies(df_refined, columns=categorical_columns, drop_first=True)

# filling the NaN values to 0
ohe_df.fillna(0,inplace=True)

ohe_df.head()
# Out:
# Categorical Columns: ['building type_1 BHK', 'building type_2 BHK', 'building type_3 BHK', 'building type_4 BHK', 'building type_5 BHK', 'building type_6 BHK', 'building type_1 RK', 'building type_Land']
#                              area low 1 BHK  area high 1 BHK  price low 1 BHK  \
# PropertyName
# Smartworld One DXP                      0.0              0.0              0.0
# M3M Crown                               0.0              0.0              0.0
# Adani Brahma Samsara Vilasa             0.0              0.0              0.0
# Sobha City                              0.0              0.0              0.0
# Signature Global City 93                0.0              0.0              0.0
#
#                              price high 1 BHK  area low 2 BHK  \
# PropertyName
# Smartworld One DXP                        0.0          1370.0
# M3M Crown                                 0.0             0.0
# Adani Brahma Samsara Vilasa               0.0             0.0
# Sobha City                                0.0          1381.0
# Signature Global City 93                  0.0           981.0
#
#                              area high 2 BHK  price low 2 BHK  \
# PropertyName
# Smartworld One DXP                    1370.0           2.0000
# M3M Crown                                0.0           0.0000
# Adani Brahma Samsara Vilasa              0.0           0.0000
# Sobha City                            1692.0           1.5500
# Signature Global City 93              1118.0           0.9301
#
#                              price high 2 BHK  area low 3 BHK  \
# PropertyName
# Smartworld One DXP                       2.40          1850.0
# M3M Crown                                0.00          1605.0
# Adani Brahma Samsara Vilasa              0.00          1800.0
# Sobha City                               3.21          1711.0
# Signature Global City 93                 1.06          1235.0
#
#                              area high 3 BHK  ...  \
# PropertyName                                  ...
# Smartworld One DXP                    2050.0  ...
# M3M Crown                             2170.0  ...
# Adani Brahma Samsara Vilasa           3150.0  ...
# Sobha City                            2343.0  ...
# Signature Global City 93              1530.0  ...
#
#                              building type_2 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                  False
# Sobha City                                                   False
# Signature Global City 93                                      True
#
#                              building type_2 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                  False
# Sobha City                                                   False
# Signature Global City 93                                     False
#
#                              building type_3 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                   True
# Sobha City                                                   False
# Signature Global City 93                                      True
#
#                              building type_3 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                  False
# Sobha City                                                   False
# Signature Global City 93                                     False
#
#                              building type_3 BHK_Villa  \
# PropertyName
# Smartworld One DXP                               False
# M3M Crown                                        False
# Adani Brahma Samsara Vilasa                      False
# Sobha City                                       False
# Signature Global City 93                         False
#
#                              building type_4 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                   True
# Sobha City                                                   False
# Signature Global City 93                                     False
#
#                              building type_4 BHK_Villa  \
# PropertyName
# Smartworld One DXP                               False
# M3M Crown                                        False
# Adani Brahma Samsara Vilasa                      False
# Sobha City                                       False
# Signature Global City 93                         False
#
#                              building type_5 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                  False
# Sobha City                                                   False
# Signature Global City 93                                     False
#
#                              building type_5 BHK_Villa  \
# PropertyName
# Smartworld One DXP                               False
# M3M Crown                                        False
# Adani Brahma Samsara Vilasa                      False
# Sobha City                                       False
# Signature Global City 93                         False
#
#                              building type_6 BHK_Villa
# PropertyName
# Smartworld One DXP                               False
# M3M Crown                                        False
# Adani Brahma Samsara Vilasa                      False
# Sobha City                                       False
# Signature Global City 93                         False
#
# [5 rows x 43 columns]

# %% [markdown]
# #### Step2 : Scaling the data

# %% [markdown]
# - Since the data is not in the same scale, we need to scale the data.

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Apply the scaler to the entire dataframe
ohe_df_normalized = pd.DataFrame(scaler.fit_transform(ohe_df), columns=ohe_df.columns, index=ohe_df.index)
ohe_df_normalized.head()
# Out:
#                              area low 1 BHK  area high 1 BHK  price low 1 BHK  \
# PropertyName
# Smartworld One DXP                -0.252266        -0.169584        -0.105197
# M3M Crown                         -0.252266        -0.169584        -0.105197
# Adani Brahma Samsara Vilasa       -0.252266        -0.169584        -0.105197
# Sobha City                        -0.252266        -0.169584        -0.105197
# Signature Global City 93          -0.252266        -0.169584        -0.105197
#
#                              price high 1 BHK  area low 2 BHK  \
# PropertyName
# Smartworld One DXP                  -0.082332        1.223499
# M3M Crown                           -0.082332       -0.893541
# Adani Brahma Samsara Vilasa         -0.082332       -0.893541
# Sobha City                          -0.082332        1.240497
# Signature Global City 93            -0.082332        0.622383
#
#                              area high 2 BHK  price low 2 BHK  \
# PropertyName
# Smartworld One DXP                  1.020101        -0.173712
# M3M Crown                          -0.896660        -0.283546
# Adani Brahma Samsara Vilasa        -0.896660        -0.283546
# Sobha City                          1.470610        -0.198425
# Signature Global City 93            0.667529        -0.232468
#
#                              price high 2 BHK  area low 3 BHK  \
# PropertyName
# Smartworld One DXP                   1.158423        0.553787
# M3M Crown                           -0.387986        0.293086
# Adani Brahma Samsara Vilasa         -0.387986        0.500583
# Sobha City                           1.680336        0.405879
# Signature Global City 93             0.295011       -0.100626
#
#                              area high 3 BHK  ...  \
# PropertyName                                  ...
# Smartworld One DXP                  0.370864  ...
# M3M Crown                           0.472749  ...
# Adani Brahma Samsara Vilasa         1.304803  ...
# Sobha City                          0.619632  ...
# Signature Global City 93           -0.070634  ...
#
#                              building type_2 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.289310
# M3M Crown                                                -0.289310
# Adani Brahma Samsara Vilasa                              -0.289310
# Sobha City                                               -0.289310
# Signature Global City 93                                  3.456497
#
#                              building type_2 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                       -0.063888
# M3M Crown                                                -0.063888
# Adani Brahma Samsara Vilasa                              -0.063888
# Sobha City                                               -0.063888
# Signature Global City 93                                 -0.063888
#
#                              building type_3 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.372678
# M3M Crown                                                -0.372678
# Adani Brahma Samsara Vilasa                               2.683282
# Sobha City                                               -0.372678
# Signature Global City 93                                  2.683282
#
#                              building type_3 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                       -0.063888
# M3M Crown                                                -0.063888
# Adani Brahma Samsara Vilasa                              -0.063888
# Sobha City                                               -0.063888
# Signature Global City 93                                 -0.063888
#
#                              building type_3 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.171139
# M3M Crown                                    -0.171139
# Adani Brahma Samsara Vilasa                  -0.171139
# Sobha City                                   -0.171139
# Signature Global City 93                     -0.171139
#
#                              building type_4 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.254824
# M3M Crown                                                -0.254824
# Adani Brahma Samsara Vilasa                               3.924283
# Sobha City                                               -0.254824
# Signature Global City 93                                 -0.254824
#
#                              building type_4 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.236208
# M3M Crown                                    -0.236208
# Adani Brahma Samsara Vilasa                  -0.236208
# Sobha City                                   -0.236208
# Signature Global City 93                     -0.236208
#
#                              building type_5 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.111111
# M3M Crown                                                -0.111111
# Adani Brahma Samsara Vilasa                              -0.111111
# Sobha City                                               -0.111111
# Signature Global City 93                                 -0.111111
#
#                              building type_5 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.216353
# M3M Crown                                    -0.216353
# Adani Brahma Samsara Vilasa                  -0.216353
# Sobha City                                   -0.216353
# Signature Global City 93                     -0.216353
#
#                              building type_6 BHK_Villa
# PropertyName
# Smartworld One DXP                           -0.063888
# M3M Crown                                    -0.063888
# Adani Brahma Samsara Vilasa                  -0.063888
# Sobha City                                   -0.063888
# Signature Global City 93                     -0.063888
#
# [5 rows x 43 columns]

# %% [markdown]
# #### Step3 : Compute the cosine similarity matrix
# - We can use the `cosine_similarity()` function from the `sklearn.metrics.pairwise` module to compute the cosine similarity matrix.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute the cosine similarity matrix
price_cosine_similarity = cosine_similarity(ohe_df_normalized)

print("Price Cosine Similarity Matrix Shape:",price_cosine_similarity.shape)
# Out:
# Price Cosine Similarity Matrix Shape: (246, 246)

# %%
# price_cosine_similarity

# %%
ohe_df_normalized.head()
# Out:
#                              area low 1 BHK  area high 1 BHK  price low 1 BHK  \
# PropertyName
# Smartworld One DXP                -0.252266        -0.169584        -0.105197
# M3M Crown                         -0.252266        -0.169584        -0.105197
# Adani Brahma Samsara Vilasa       -0.252266        -0.169584        -0.105197
# Sobha City                        -0.252266        -0.169584        -0.105197
# Signature Global City 93          -0.252266        -0.169584        -0.105197
#
#                              price high 1 BHK  area low 2 BHK  \
# PropertyName
# Smartworld One DXP                  -0.082332        1.223499
# M3M Crown                           -0.082332       -0.893541
# Adani Brahma Samsara Vilasa         -0.082332       -0.893541
# Sobha City                          -0.082332        1.240497
# Signature Global City 93            -0.082332        0.622383
#
#                              area high 2 BHK  price low 2 BHK  \
# PropertyName
# Smartworld One DXP                  1.020101        -0.173712
# M3M Crown                          -0.896660        -0.283546
# Adani Brahma Samsara Vilasa        -0.896660        -0.283546
# Sobha City                          1.470610        -0.198425
# Signature Global City 93            0.667529        -0.232468
#
#                              price high 2 BHK  area low 3 BHK  \
# PropertyName
# Smartworld One DXP                   1.158423        0.553787
# M3M Crown                           -0.387986        0.293086
# Adani Brahma Samsara Vilasa         -0.387986        0.500583
# Sobha City                           1.680336        0.405879
# Signature Global City 93             0.295011       -0.100626
#
#                              area high 3 BHK  ...  \
# PropertyName                                  ...
# Smartworld One DXP                  0.370864  ...
# M3M Crown                           0.472749  ...
# Adani Brahma Samsara Vilasa         1.304803  ...
# Sobha City                          0.619632  ...
# Signature Global City 93           -0.070634  ...
#
#                              building type_2 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.289310
# M3M Crown                                                -0.289310
# Adani Brahma Samsara Vilasa                              -0.289310
# Sobha City                                               -0.289310
# Signature Global City 93                                  3.456497
#
#                              building type_2 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                       -0.063888
# M3M Crown                                                -0.063888
# Adani Brahma Samsara Vilasa                              -0.063888
# Sobha City                                               -0.063888
# Signature Global City 93                                 -0.063888
#
#                              building type_3 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.372678
# M3M Crown                                                -0.372678
# Adani Brahma Samsara Vilasa                               2.683282
# Sobha City                                               -0.372678
# Signature Global City 93                                  2.683282
#
#                              building type_3 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                       -0.063888
# M3M Crown                                                -0.063888
# Adani Brahma Samsara Vilasa                              -0.063888
# Sobha City                                               -0.063888
# Signature Global City 93                                 -0.063888
#
#                              building type_3 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.171139
# M3M Crown                                    -0.171139
# Adani Brahma Samsara Vilasa                  -0.171139
# Sobha City                                   -0.171139
# Signature Global City 93                     -0.171139
#
#                              building type_4 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.254824
# M3M Crown                                                -0.254824
# Adani Brahma Samsara Vilasa                               3.924283
# Sobha City                                               -0.254824
# Signature Global City 93                                 -0.254824
#
#                              building type_4 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.236208
# M3M Crown                                    -0.236208
# Adani Brahma Samsara Vilasa                  -0.236208
# Sobha City                                   -0.236208
# Signature Global City 93                     -0.236208
#
#                              building type_5 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.111111
# M3M Crown                                                -0.111111
# Adani Brahma Samsara Vilasa                              -0.111111
# Sobha City                                               -0.111111
# Signature Global City 93                                 -0.111111
#
#                              building type_5 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.216353
# M3M Crown                                    -0.216353
# Adani Brahma Samsara Vilasa                  -0.216353
# Sobha City                                   -0.216353
# Signature Global City 93                     -0.216353
#
#                              building type_6 BHK_Villa
# PropertyName
# Smartworld One DXP                           -0.063888
# M3M Crown                                    -0.063888
# Adani Brahma Samsara Vilasa                  -0.063888
# Sobha City                                   -0.063888
# Signature Global City 93                     -0.063888
#
# [5 rows x 43 columns]

# %% [markdown]
# #### Step4 : Get the recommendations for a property based on `price`

# %%
def recommend_properties_with_scores(property_name, cosine_sim_matrix=price_cosine_similarity):
    
    print("property_name:",ohe_df_normalized.index)

    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosine_sim_matrix[ohe_df_normalized.index.get_loc(property_name)]))
    print("sim_scores:",sim_scores)
    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the 10 most similar properties
    top_indices = [i[0] for i in sorted_scores[1:11]]
    top_scores = [i[1] for i in sorted_scores[1:11]]
    
    # Retrieve the names of the top properties using the indices
    top_properties = ohe_df_normalized.index[top_indices].tolist()
    
    # Create a dataframe with the results
    recommendations_df = pd.DataFrame({
        'PropertyName': top_properties,
        'SimilarityScore': top_scores
    })
    recommendations_df.sort_values(by='SimilarityScore',ascending=False,inplace=True)

    return recommendations_df

# Test the recommender function using a property name
recommend_properties_with_scores('M3M Golf Hills')
# Out:
# property_name: Index(['Smartworld One DXP', 'M3M Crown', 'Adani Brahma Samsara Vilasa',
#        'Sobha City', 'Signature Global City 93', 'Whiteland The Aspen',
#        'Bestech Altura', 'Elan The Presidential', 'Signature Global City 92',
#        'Emaar Digihomes',
#        ...
#        'BPTP Freedom Park Life', 'DLF New Town Heights', 'La Lagune',
#        'M3M My Den', 'Suncity Avenue 102', 'DLF Princeton Estate',
#        'Pyramid Urban Homes 2', 'Satya The Hermitage', 'BPTP Spacio',
#        'SS The Coralwood'],
#       dtype='object', name='PropertyName', length=246)
# sim_scores: [(0, 0.9546700864873817), (1, 0.08409611940567058), (2, -0.05829344488388788), (3, 0.9287476321360774), (4, -0.004120903683722767), (5, -0.007134521438047111), (6, 0.01173862009627188), (7, 0.007557134631267208), (8, 0.03247169603663095), (9, 0.6542186364853977), (10, 0.02476155627265135), (11, -0.06381519846536686), (12, 0.37221033073650706), (13, -0.20962601131349895), (14, -0.2807636761548084), (15, 0.07169851745889502), (16, 1.0000000000000009), (17, -0.18555460738074256), (18, -0.2649441623295805), (19, 0.32154001974562374), (20, 0.024796763388161714), (21, 0.14962517343083134), (22, 0.9511561073306115), (23, 0.1321304325188533), (24, 0.6052118615099863), (25, 0.10014036555763234), (26, 0.01198682201690113), (27, 0.6228976990631024), (28, -0.054489084656305455), (29, 0.9431284475619686), (30, 0.6061378621957183), (31, -0.30866457289267896), (32, 0.3495002544054879), (33, 0.5574372428007103), (34, 0.2279481762120528), (35, 0.025956909919236233), (36, -0.10017672985930616), (37, 0.026027014383870152), (38, -0.31291413125538686), (39, -0.4374454081996551), (40, -0.27314484184427074), (41, -0.1134486622120619), (42, 0.3262088271976864), (43, 0.10608689118102914), (44, -0.17249254997575017), (45, -0.03984083967712665), (46, -0.181517952876097), (47, 0.4362917283488021), (48, 0.18862798962156327), (49, -0.2521929789904282), (50, -0.1943701312635163), (51, 0.5492401875307478), (52, -0.11621886893134714), (53, 0.0430084023114391), (54, 0.09450490432591281), (55, 0.5750791020080813), (56, -0.12753323841508768), (57, -0.1365614658898199), (58, -0.34356131326075434), (59, 0.024203356795326102), (60, 0.21677378343344544), (61, -0.05513148233863835), (62, -0.5163776487901472), (63, -0.21031147109835224), (64, -0.4428193418404465), (65, -0.22734732236098873), (66, -0.17924751301271657), (67, -0.3647309750737094), (68, -0.4979151446811943), (69, 0.07013556544941181), (70, -0.2171444400419754), (71, 0.12999040938231865), (72, -0.5252862251428376), (73, 0.9173448963815636), (74, 0.4045140505502527), (75, -0.3378045188406536), (76, 0.007710034641843748), (77, 0.8456419301048558), (78, -0.08333342064310803), (79, 0.9159910936888963), (80, 0.9554620840555186), (81, -0.1938475484131113), (82, -0.4801950952865183), (83, -0.1814434488311316), (84, -0.4480615111994878), (85, 0.05176782634254002), (86, -0.35511039654007814), (87, -0.33969867108601587), (88, 0.4941665564069665), (89, -0.4553993173406911), (90, 0.5495328930535703), (91, 0.6455901962085038), (92, -0.5262872934050777), (93, 0.4211532825973544), (94, -0.26060290507880535), (95, -0.06500020597560735), (96, 0.3868749887873256), (97, 0.017212435406605473), (98, -0.24068115019516406), (99, 0.7266469484437669), (100, -0.15940142591115888), (101, -0.1637160296279253), (102, 0.18724751643765702), (103, 0.019192091088425976), (104, 0.3656289121074679), (105, -0.4984172495848612), (106, 0.24732429216728283), (107, 0.3887153202734185), (108, -0.5215014207703645), (109, -0.27630368718714277), (110, -0.19315241185799042), (111, -0.07789541435323188), (112, 0.5820440141347379), (113, 0.2264954281473817), (114, -0.17426163684460574), (115, -0.4410825426745348), (116, -0.16480051937580112), (117, 0.012852066038627652), (118, 0.7643197400045045), (119, 0.5268347920244036), (120, -0.076339316260892), (121, 0.5570905031681533), (122, 0.6216213832692592), (123, 0.6156578779854072), (124, 0.912314656029016), (125, -0.16863430228354973), (126, 0.6110125583074314), (127, 0.8859970653455552), (128, -0.31279287447429716), (129, -0.22052755744338387), (130, 0.9192305211008146), (131, 0.23363757102931945), (132, -0.49783750250677866), (133, 0.6421769488770003), (134, -0.49809819433783387), (135, -0.16752277755787193), (136, -0.07101515286630761), (137, 0.6679839556587375), (138, -0.49793364302016124), (139, -0.19126395548918407), (140, 0.3303018121160016), (141, -0.26376216996959495), (142, 0.225048625535476), (143, 0.06738010611545833), (144, -0.01686075527309002), (145, 0.03703815668762146), (146 ...
#               PropertyName  SimilarityScore
# 0  AIPL The Peaceful Homes         0.955462
# 1       Smartworld One DXP         0.954670
# 2           Unitech Escape         0.953092
# 3              M3M Capital         0.951156
# 4               BPTP Terra         0.943128
# 5               Sobha City         0.928748
# 6          Unitech Harmony         0.925164
# 7             Corona Optus         0.919231
# 8         Puri Emerald Bay         0.917345
# 9               Ireo Skyon         0.915991

# %% [markdown]
# ---

# %% [markdown]
# ## **Recommendation System 3 : Based on `Location`**

# %% [markdown]
# #### Step1 : pre-processing the `LocationAdvantages` column
#
# - Extract the distances for each location

# %%
df[['PropertyName','LocationAdvantages','Link']]
# Out:
#                     PropertyName  \
# 0             Smartworld One DXP
# 1                      M3M Crown
# 2    Adani Brahma Samsara Vilasa
# 3                     Sobha City
# 4       Signature Global City 93
# ..                           ...
# 242         DLF Princeton Estate
# 243        Pyramid Urban Homes 2
# 244          Satya The Hermitage
# 245                  BPTP Spacio
# 246             SS The Coralwood
#
#                                     LocationAdvantages  \
# 0    {'Bajghera Road': '800 Meter', 'Palam Vihar Ha...
# 1    {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The N...
# 2    {'AIPL Business Club Sector 62': '2.7 Km', 'He...
# 3    {'The Shikshiyan School': '2.9 KM', 'WTC Plaza...
# 4    {'Pranavananda Int. School': '450 m', 'DLF Sit...
# ..                                                 ...
# 242  {'Sector 42-43 Metro Station': '1.8 Km', 'Para...
# 243  {'Aarvy Healthcare Super Speciality': '1.8 KM'...
# 244  {'Dwarka Expressway': '1.2 Km', 'S N Internati...
# 245  {'Suncity School': '0.2 Km', 'Gurugram Road': ...
# 246  {'Sector 84 Road': '600 Meter', 'Delhi Public ...
#
#                                                   Link
# 0    https://www.99acres.com/smartworld-one-dxp-sec...
# 1    https://www.99acres.com/m3m-crown-sector-111-g...
# 2    https://www.99acres.com/adani-brahma-samsara-v...
# 3    https://www.99acres.com/sobha-city-sector-108-...
# 4    https://www.99acres.com/signature-global-city-...
# ..                                                 ...
# 242  https://www.99acres.com/dlf-princeton-estate-d...
# 243  https://www.99acres.com/pyramid-urban-homes-2-...
# 244  https://www.99acres.com/satya-the-hermitage-se...
# 245  https://www.99acres.com/bptp-spacio-sector-37d...
# 246  https://www.99acres.com/ss-the-coralwood-secto...
#
# [246 rows x 3 columns]

# %%
df1 = df[['PropertyName','Link']]
df1
# Out:
#                     PropertyName  \
# 0             Smartworld One DXP
# 1                      M3M Crown
# 2    Adani Brahma Samsara Vilasa
# 3                     Sobha City
# 4       Signature Global City 93
# ..                           ...
# 242         DLF Princeton Estate
# 243        Pyramid Urban Homes 2
# 244          Satya The Hermitage
# 245                  BPTP Spacio
# 246             SS The Coralwood
#
#                                                   Link
# 0    https://www.99acres.com/smartworld-one-dxp-sec...
# 1    https://www.99acres.com/m3m-crown-sector-111-g...
# 2    https://www.99acres.com/adani-brahma-samsara-v...
# 3    https://www.99acres.com/sobha-city-sector-108-...
# 4    https://www.99acres.com/signature-global-city-...
# ..                                                 ...
# 242  https://www.99acres.com/dlf-princeton-estate-d...
# 243  https://www.99acres.com/pyramid-urban-homes-2-...
# 244  https://www.99acres.com/satya-the-hermitage-se...
# 245  https://www.99acres.com/bptp-spacio-sector-37d...
# 246  https://www.99acres.com/ss-the-coralwood-secto...
#
# [246 rows x 2 columns]

# %%
# Function to convert the distance to meters
def distance_to_meters(distance_str):
    try:
        # Check if the distance is in kilometers
        if 'Km' in distance_str or 'KM' in distance_str:
            return float(distance_str.split()[0]) * 1000
        # Check if the distance is in meters
        elif 'Meter' in distance_str or 'meter' in distance_str:
            return float(distance_str.split()[0])
        else:
            return None
    except:
        return None

# %%
# Extract distances for each location
location_matrix = {}
for index, row in df.iterrows():
    distances = {}
    for location, distance in ast.literal_eval(row['LocationAdvantages']).items():
        distances[location] = distance_to_meters(distance)
    location_matrix[index] = distances

# Convert the dictionary to a dataframe
location_df = pd.DataFrame.from_dict(location_matrix, orient='index')

# Display the first few rows
location_df.head()
# Out:
#     Bajghera Road  Palam Vihar Halt  DPSG Palam Vihar  Park Hospital  \
# 0           800.0            2500.0            3100.0         3100.0
# 25          550.0               NaN               NaN            NaN
# 37         5300.0               NaN               NaN            NaN
# 69         1500.0               NaN               NaN            NaN
# 9             NaN               NaN               NaN         5500.0
#
#     Gurgaon Railway Station  The NorthCap University  Dwarka Expy  \
# 0                    4900.0                   5400.0       1200.0
# 25                      NaN                   6700.0       3800.0
# 37                   2500.0                   8800.0          NaN
# 69                   6500.0                   6700.0       5100.0
# 9                       NaN                      NaN          NaN
#
#     Hyatt Place Gurgaon Udyog Vihar  Dwarka Sector 21, Metro Station  \
# 0                            7700.0                           7200.0
# 25                              NaN                              NaN
# 37                              NaN                              NaN
# 69                              NaN                              NaN
# 9                               NaN                              NaN
#
#     Pacific D21 Mall  ...  MCC Cricket Ground Dhankot  \
# 0             7400.0  ...                         NaN
# 25            7500.0  ...                         NaN
# 37               NaN  ...                         NaN
# 69            8200.0  ...                         NaN
# 9                NaN  ...                         NaN
#
#     The Shri Ram School Aravali  Taj City Centre Gurugram  \
# 0                           NaN                       NaN
# 25                          NaN                       NaN
# 37                          NaN                       NaN
# 69                          NaN                       NaN
# 9                           NaN                       NaN
#
#     Minda Industries  Corporate Office  Rampura Flyover, Naurangpur Rd  \
# 0                                  NaN                             NaN
# 25                                 NaN                             NaN
# 37                                 NaN                             NaN
# 69                                 NaN                             NaN
# 9                                  NaN                             NaN
#
#     Manesar toll plaza - Kherki Daula  Imt Manesar, Gurugram  Holiday Inn  \
# 0                                 NaN                    NaN          NaN
# 25                                NaN                    NaN          NaN
# 37                                NaN                    NaN          NaN
# 69                                NaN                    NaN          NaN
# 9                                 NaN                    NaN          NaN
#
#     Sector 84 Road  Skyview Corporate Park
# 0              NaN                     NaN
# 25             NaN                     NaN
# 37             NaN                     NaN
# 69             NaN                     NaN
# 9              NaN                     NaN
#
# [5 rows x 1070 columns]

# %%
len(location_df.columns)
# Out:
# 1070

# %% [markdown]
# ---
#
# - We will find and merge columns with similar names based on a similarity threshold. Adjust the threshold parameter as needed to control the sensitivity of the similarity matching.

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
import pickle

# Function to find similar columns
def find_similar_columns(columns, threshold=95):
    similar_columns = {}
    for col in columns:
        matches = process.extract(col, columns, limit=len(columns))
        for match in matches:
            if match[1] >= threshold and match[0] != col:
                if col not in similar_columns:
                    similar_columns[col] = []
                similar_columns[col].append(match[0])
    return similar_columns

# Find similar columns
columns = location_df.columns.tolist()
similar_columns = find_similar_columns(columns)

# Print shape before merging
print("Shape before merging:", location_df.shape)

# Merge similar columns
for key, values in similar_columns.items():
    if key in location_df.columns:
        for value in values:
            if value in location_df.columns:
                location_df[key] = location_df[[key, value]].min(axis=1)
                location_df.drop(columns=[value], inplace=True)

# Print shape after merging
print("Shape after merging:", location_df.shape)

with open('similar_columns.pkl', 'wb') as f:
    pickle.dump(similar_columns, f)
# Out:
# Shape before merging: (246, 1070)
# Shape after merging: (246, 901)

# %% [markdown]
# ---

# %%
location_df.head()
# Out:
#     Bajghera Road  Palam Vihar Halt  DPSG Palam Vihar  Park Hospital  \
# 0           800.0            2500.0            3100.0         3100.0
# 25          550.0               NaN               NaN            NaN
# 37         5300.0               NaN               NaN            NaN
# 69         1500.0               NaN               NaN            NaN
# 9             NaN               NaN               NaN         5500.0
#
#     Gurgaon Railway Station  The NorthCap University  Dwarka Expy  \
# 0                    4900.0                   5400.0       1200.0
# 25                      NaN                   6700.0       3800.0
# 37                   2500.0                   8800.0          NaN
# 69                   6500.0                   6700.0       5100.0
# 9                       NaN                      NaN          NaN
#
#     Hyatt Place Gurgaon Udyog Vihar  Dwarka Sector 21, Metro Station  \
# 0                            7700.0                           7200.0
# 25                              NaN                              NaN
# 37                              NaN                              NaN
# 69                              NaN                           8100.0
# 9                               NaN                              NaN
#
#     Pacific D21 Mall  ...  MCC Cricket Ground Dhankot  \
# 0             7400.0  ...                         NaN
# 25            7500.0  ...                         NaN
# 37               NaN  ...                         NaN
# 69            8200.0  ...                         NaN
# 9                NaN  ...                         NaN
#
#     The Shri Ram School Aravali  Taj City Centre Gurugram  \
# 0                           NaN                       NaN
# 25                          NaN                       NaN
# 37                          NaN                       NaN
# 69                          NaN                       NaN
# 9                           NaN                       NaN
#
#     Minda Industries  Corporate Office  Rampura Flyover, Naurangpur Rd  \
# 0                                  NaN                             NaN
# 25                                 NaN                             NaN
# 37                                 NaN                             NaN
# 69                                 NaN                             NaN
# 9                                  NaN                             NaN
#
#     Manesar toll plaza - Kherki Daula  Imt Manesar, Gurugram  Holiday Inn  \
# 0                                 NaN                    NaN          NaN
# 25                                NaN                    NaN          NaN
# 37                                NaN                    NaN          NaN
# 69                                NaN                    NaN          NaN
# 9                                 NaN                    NaN          NaN
#
#     Sector 84 Road  Skyview Corporate Park
# 0              NaN                     NaN
# 25             NaN                     NaN
# 37             NaN                     NaN
# 69             NaN                     NaN
# 9              NaN                     NaN
#
# [5 rows x 901 columns]

# %%
# Fill NaN values with the maximum value in the whole dataframe

max_value = location_df.max().max()
print("max_value in location_df:",max_value)

location_df.fillna(max_value, inplace=True)
location_df.head()
# Out:
# max_value in location_df: 54500.0
#     Bajghera Road  Palam Vihar Halt  DPSG Palam Vihar  Park Hospital  \
# 0           800.0            2500.0            3100.0         3100.0
# 25          550.0           54500.0           54500.0        54500.0
# 37         5300.0           54500.0           54500.0        54500.0
# 69         1500.0           54500.0           54500.0        54500.0
# 9         54500.0           54500.0           54500.0         5500.0
#
#     Gurgaon Railway Station  The NorthCap University  Dwarka Expy  \
# 0                    4900.0                   5400.0       1200.0
# 25                  54500.0                   6700.0       3800.0
# 37                   2500.0                   8800.0      54500.0
# 69                   6500.0                   6700.0       5100.0
# 9                   54500.0                  54500.0      54500.0
#
#     Hyatt Place Gurgaon Udyog Vihar  Dwarka Sector 21, Metro Station  \
# 0                            7700.0                           7200.0
# 25                          54500.0                          54500.0
# 37                          54500.0                          54500.0
# 69                          54500.0                           8100.0
# 9                           54500.0                          54500.0
#
#     Pacific D21 Mall  ...  MCC Cricket Ground Dhankot  \
# 0             7400.0  ...                     54500.0
# 25            7500.0  ...                     54500.0
# 37           54500.0  ...                     54500.0
# 69            8200.0  ...                     54500.0
# 9            54500.0  ...                     54500.0
#
#     The Shri Ram School Aravali  Taj City Centre Gurugram  \
# 0                       54500.0                   54500.0
# 25                      54500.0                   54500.0
# 37                      54500.0                   54500.0
# 69                      54500.0                   54500.0
# 9                       54500.0                   54500.0
#
#     Minda Industries  Corporate Office  Rampura Flyover, Naurangpur Rd  \
# 0                              54500.0                         54500.0
# 25                             54500.0                         54500.0
# 37                             54500.0                         54500.0
# 69                             54500.0                         54500.0
# 9                              54500.0                         54500.0
#
#     Manesar toll plaza - Kherki Daula  Imt Manesar, Gurugram  Holiday Inn  \
# 0                             54500.0                54500.0      54500.0
# 25                            54500.0                54500.0      54500.0
# 37                            54500.0                54500.0      54500.0
# 69                            54500.0                54500.0      54500.0
# 9                             54500.0                54500.0      54500.0
#
#     Sector 84 Road  Skyview Corporate Park
# 0          54500.0                 54500.0
# 25         54500.0                 54500.0
# 37         54500.0                 54500.0
# 69         54500.0                 54500.0
# 9          54500.0                 54500.0
#
# [5 rows x 901 columns]

# %% [markdown]
# ---

# %%
location_df.index = df.PropertyName
location_df.head()
# Out:
#                              Bajghera Road  Palam Vihar Halt  \
# PropertyName
# Smartworld One DXP                   800.0            2500.0
# M3M Crown                            550.0           54500.0
# Adani Brahma Samsara Vilasa         5300.0           54500.0
# Sobha City                          1500.0           54500.0
# Signature Global City 93           54500.0           54500.0
#
#                              DPSG Palam Vihar  Park Hospital  \
# PropertyName
# Smartworld One DXP                     3100.0         3100.0
# M3M Crown                             54500.0        54500.0
# Adani Brahma Samsara Vilasa           54500.0        54500.0
# Sobha City                            54500.0        54500.0
# Signature Global City 93              54500.0         5500.0
#
#                              Gurgaon Railway Station  The NorthCap University  \
# PropertyName
# Smartworld One DXP                            4900.0                   5400.0
# M3M Crown                                    54500.0                   6700.0
# Adani Brahma Samsara Vilasa                   2500.0                   8800.0
# Sobha City                                    6500.0                   6700.0
# Signature Global City 93                     54500.0                  54500.0
#
#                              Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# PropertyName
# Smartworld One DXP                1200.0                           7700.0
# M3M Crown                         3800.0                          54500.0
# Adani Brahma Samsara Vilasa      54500.0                          54500.0
# Sobha City                        5100.0                          54500.0
# Signature Global City 93         54500.0                          54500.0
#
#                              Dwarka Sector 21, Metro Station  \
# PropertyName
# Smartworld One DXP                                    7200.0
# M3M Crown                                            54500.0
# Adani Brahma Samsara Vilasa                          54500.0
# Sobha City                                            8100.0
# Signature Global City 93                             54500.0
#
#                              Pacific D21 Mall  ...  \
# PropertyName                                   ...
# Smartworld One DXP                     7400.0  ...
# M3M Crown                              7500.0  ...
# Adani Brahma Samsara Vilasa           54500.0  ...
# Sobha City                             8200.0  ...
# Signature Global City 93              54500.0  ...
#
#                              MCC Cricket Ground Dhankot  \
# PropertyName
# Smartworld One DXP                              54500.0
# M3M Crown                                       54500.0
# Adani Brahma Samsara Vilasa                     54500.0
# Sobha City                                      54500.0
# Signature Global City 93                        54500.0
#
#                              The Shri Ram School Aravali  \
# PropertyName
# Smartworld One DXP                               54500.0
# M3M Crown                                        54500.0
# Adani Brahma Samsara Vilasa                      54500.0
# Sobha City                                       54500.0
# Signature Global City 93                         54500.0
#
#                              Taj City Centre Gurugram  \
# PropertyName
# Smartworld One DXP                            54500.0
# M3M Crown                                     54500.0
# Adani Brahma Samsara Vilasa                   54500.0
# Sobha City                                    54500.0
# Signature Global City 93                      54500.0
#
#                              Minda Industries  Corporate Office  \
# PropertyName
# Smartworld One DXP                                      54500.0
# M3M Crown                                               54500.0
# Adani Brahma Samsara Vilasa                             54500.0
# Sobha City                                              54500.0
# Signature Global City 93                                54500.0
#
#                              Rampura Flyover, Naurangpur Rd  \
# PropertyName
# Smartworld One DXP                                  54500.0
# M3M Crown                                           54500.0
# Adani Brahma Samsara Vilasa                         54500.0
# Sobha City                                          54500.0
# Signature Global City 93                            54500.0
#
#                              Manesar toll plaza - Kherki Daula  \
# PropertyName
# Smartworld One DXP                                     54500.0
# M3M Crown                                              54500.0
# Adani Brahma Samsara Vilasa                            54500.0
# Sobha City                                             54500.0
# Signature Global City 93                               54500.0
#
#                              Imt Manesar, Gurugram  Holiday Inn  \
# PropertyName
# Smartworld One DXP                         54500.0      54500.0
# M3M Crown                                  54500.0      54500.0
# Adani Brahma Samsara Vilasa                54500.0      54500.0
# Sobha City                                 54500.0      54500.0
# Signature Global City 93                   54500.0      54500.0
#
#                              Sector 84 Road  Skyview Corporate Park
# PropertyName
# Smartworld One DXP                  54500.0                 54500.0
# M3M Crown                           54500.0                 54500.0
# Adani Brahma Samsara Vilasa         54500.0                 54500.0
# Sobha City                          54500.0                 54500.0
# Signature Global City 93            54500.0                 54500.0
#
# [5 rows x 901 columns]

# %%
# Assuming location_df and df1 are already defined
location_df = location_df.merge(df1, on='PropertyName', how='left')
location_df
# Out:
#                     PropertyName  Bajghera Road  Palam Vihar Halt  \
# 0             Smartworld One DXP          800.0            2500.0
# 1                      M3M Crown          550.0           54500.0
# 2    Adani Brahma Samsara Vilasa         5300.0           54500.0
# 3                     Sobha City         1500.0           54500.0
# 4       Signature Global City 93        54500.0           54500.0
# ..                           ...            ...               ...
# 241         DLF Princeton Estate        54500.0           54500.0
# 242        Pyramid Urban Homes 2        54500.0           54500.0
# 243          Satya The Hermitage        54500.0           54500.0
# 244                  BPTP Spacio        54500.0           54500.0
# 245             SS The Coralwood        54500.0           54500.0
#
#      DPSG Palam Vihar  Park Hospital  Gurgaon Railway Station  \
# 0              3100.0         3100.0                   4900.0
# 1             54500.0        54500.0                  54500.0
# 2             54500.0        54500.0                   2500.0
# 3             54500.0        54500.0                   6500.0
# 4             54500.0         5500.0                  54500.0
# ..                ...            ...                      ...
# 241           54500.0        54500.0                  54500.0
# 242           54500.0        54500.0                  54500.0
# 243           54500.0        54500.0                  54500.0
# 244           54500.0        54500.0                  54500.0
# 245           54500.0        54500.0                  54500.0
#
#      The NorthCap University  Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# 0                     5400.0       1200.0                           7700.0
# 1                     6700.0       3800.0                          54500.0
# 2                     8800.0      54500.0                          54500.0
# 3                     6700.0       5100.0                          54500.0
# 4                    54500.0      54500.0                          54500.0
# ..                       ...          ...                              ...
# 241                  54500.0      54500.0                          54500.0
# 242                  54500.0      54500.0                          54500.0
# 243                  54500.0      54500.0                          54500.0
# 244                  54500.0      54500.0                          54500.0
# 245                  54500.0      54500.0                          54500.0
#
#      Dwarka Sector 21, Metro Station  ...  The Shri Ram School Aravali  \
# 0                             7200.0  ...                      54500.0
# 1                            54500.0  ...                      54500.0
# 2                            54500.0  ...                      54500.0
# 3                             8100.0  ...                      54500.0
# 4                            54500.0  ...                      54500.0
# ..                               ...  ...                          ...
# 241                          54500.0  ...                      54500.0
# 242                          54500.0  ...                      54500.0
# 243                          54500.0  ...                      54500.0
# 244                          54500.0  ...                      54500.0
# 245                          54500.0  ...                      54500.0
#
#      Taj City Centre Gurugram  Minda Industries  Corporate Office  \
# 0                     54500.0                             54500.0
# 1                     54500.0                             54500.0
# 2                     54500.0                             54500.0
# 3                     54500.0                             54500.0
# 4                     54500.0                             54500.0
# ..                        ...                                 ...
# 241                   54500.0                             54500.0
# 242                   54500.0                             54500.0
# 243                   54500.0                             54500.0
# 244                   54500.0                             54500.0
# 245                   54500.0                             54500.0
#
#      Rampura Flyover, Naurangpur Rd  Manesar toll plaza - Kherki Daula  \
# 0                           54500.0                            54500.0
# 1                           54500.0                            54500.0
# 2                           54500.0                            54500.0
# 3                           54500.0                            54500.0
# 4                           54500.0                            54500.0
# ..                              ...                                ...
# 241                         54500.0                            54500.0
# 242                         54500.0                            54500.0
# 243                         54500.0                            54500.0
# 244                         54500.0                            54500.0
# 245                         54500.0                            54500.0
#
#      Imt Manesar, Gurugram  Holiday Inn  Sector 84 Road  \
# 0                  54500.0      54500.0         54500.0
# 1                  54500.0      54500.0         54500.0
# 2                  54500.0      54500.0         54500.0
# 3                  54500.0      54500.0         54500.0
# 4                  54500.0      54500.0         54500.0
# ..                     ...          ...             ...
# 241                54500.0      54500.0         54500.0
# 242                54500.0      54500.0         54500.0
# 243                54500.0      54500.0         54500.0
# 244                54500.0      54500.0         54500.0
# 245                54500.0      54500.0         54500.0
#
#      Skyview Corporate Park                                               Link
# 0                   54500.0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1                   54500.0  https://www.99acres.com/m3m-crown-sector-111-g...
# 2                   54500.0  https://www.99acres.com/adani-brahma-samsara-v...
# 3                   54500.0  https://www.99acres.com/sobha-city-sector-108-...
# 4                   54500.0  https://www.99acres.com/signature-global-city-...
# ..                      ...                                                ...
# 241                 54500.0  https://www.99acres.com/dlf-princeton-estate-d...
# 242                 54500.0  https://www.99acres.com/pyramid-urban-homes-2-...
# 243                 54500.0  https://www.99acres.com/satya-the-hermitage-se...
# 244                 54500.0  https://www.99acres.com/bptp-spacio-sector-37d...
# 245                 54500.0  https://www.99acres.com/ss-the-coralwood-secto...
#
# [246 rows x 903 columns]

# %%
# freezing this location_df, it will be used in recommendation system customization

location_df.to_pickle("../backend/models/location_df.pkl")

# %% [markdown]
# #### Step2 : Scaling the data

# %%
location_df.head()
# Out:
#                   PropertyName  Bajghera Road  Palam Vihar Halt  \
# 0           Smartworld One DXP          800.0            2500.0
# 1                    M3M Crown          550.0           54500.0
# 2  Adani Brahma Samsara Vilasa         5300.0           54500.0
# 3                   Sobha City         1500.0           54500.0
# 4     Signature Global City 93        54500.0           54500.0
#
#    DPSG Palam Vihar  Park Hospital  Gurgaon Railway Station  \
# 0            3100.0         3100.0                   4900.0
# 1           54500.0        54500.0                  54500.0
# 2           54500.0        54500.0                   2500.0
# 3           54500.0        54500.0                   6500.0
# 4           54500.0         5500.0                  54500.0
#
#    The NorthCap University  Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# 0                   5400.0       1200.0                           7700.0
# 1                   6700.0       3800.0                          54500.0
# 2                   8800.0      54500.0                          54500.0
# 3                   6700.0       5100.0                          54500.0
# 4                  54500.0      54500.0                          54500.0
#
#    Dwarka Sector 21, Metro Station  ...  The Shri Ram School Aravali  \
# 0                           7200.0  ...                      54500.0
# 1                          54500.0  ...                      54500.0
# 2                          54500.0  ...                      54500.0
# 3                           8100.0  ...                      54500.0
# 4                          54500.0  ...                      54500.0
#
#    Taj City Centre Gurugram  Minda Industries  Corporate Office  \
# 0                   54500.0                             54500.0
# 1                   54500.0                             54500.0
# 2                   54500.0                             54500.0
# 3                   54500.0                             54500.0
# 4                   54500.0                             54500.0
#
#    Rampura Flyover, Naurangpur Rd  Manesar toll plaza - Kherki Daula  \
# 0                         54500.0                            54500.0
# 1                         54500.0                            54500.0
# 2                         54500.0                            54500.0
# 3                         54500.0                            54500.0
# 4                         54500.0                            54500.0
#
#    Imt Manesar, Gurugram  Holiday Inn  Sector 84 Road  Skyview Corporate Park  \
# 0                54500.0      54500.0         54500.0                 54500.0
# 1                54500.0      54500.0         54500.0                 54500.0
# 2                54500.0      54500.0         54500.0                 54500.0
# 3                54500.0      54500.0         54500.0                 54500.0
# 4                54500.0      54500.0         54500.0                 54500.0
#
#                                                 Link
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
# [5 rows x 903 columns]

# %%
# load location_df
location_df = pd.read_pickle("../backend/models/location_df.pkl")

location_df.reset_index(drop=True, inplace=True)
# location_df.drop(columns=['Link'],inplace=True)
location_df.head()
# Out:
#                   PropertyName  Bajghera Road  Palam Vihar Halt  \
# 0           Smartworld One DXP          800.0            2500.0
# 1                    M3M Crown          550.0           54500.0
# 2  Adani Brahma Samsara Vilasa         5300.0           54500.0
# 3                   Sobha City         1500.0           54500.0
# 4     Signature Global City 93        54500.0           54500.0
#
#    DPSG Palam Vihar  Park Hospital  Gurgaon Railway Station  \
# 0            3100.0         3100.0                   4900.0
# 1           54500.0        54500.0                  54500.0
# 2           54500.0        54500.0                   2500.0
# 3           54500.0        54500.0                   6500.0
# 4           54500.0         5500.0                  54500.0
#
#    The NorthCap University  Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# 0                   5400.0       1200.0                           7700.0
# 1                   6700.0       3800.0                          54500.0
# 2                   8800.0      54500.0                          54500.0
# 3                   6700.0       5100.0                          54500.0
# 4                  54500.0      54500.0                          54500.0
#
#    Dwarka Sector 21, Metro Station  ...  The Shri Ram School Aravali  \
# 0                           7200.0  ...                      54500.0
# 1                          54500.0  ...                      54500.0
# 2                          54500.0  ...                      54500.0
# 3                           8100.0  ...                      54500.0
# 4                          54500.0  ...                      54500.0
#
#    Taj City Centre Gurugram  Minda Industries  Corporate Office  \
# 0                   54500.0                             54500.0
# 1                   54500.0                             54500.0
# 2                   54500.0                             54500.0
# 3                   54500.0                             54500.0
# 4                   54500.0                             54500.0
#
#    Rampura Flyover, Naurangpur Rd  Manesar toll plaza - Kherki Daula  \
# 0                         54500.0                            54500.0
# 1                         54500.0                            54500.0
# 2                         54500.0                            54500.0
# 3                         54500.0                            54500.0
# 4                         54500.0                            54500.0
#
#    Imt Manesar, Gurugram  Holiday Inn  Sector 84 Road  Skyview Corporate Park  \
# 0                54500.0      54500.0         54500.0                 54500.0
# 1                54500.0      54500.0         54500.0                 54500.0
# 2                54500.0      54500.0         54500.0                 54500.0
# 3                54500.0      54500.0         54500.0                 54500.0
# 4                54500.0      54500.0         54500.0                 54500.0
#
#                                                 Link
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
# [5 rows x 903 columns]

# %%
location_df.head()
# Out:
#                   PropertyName  Bajghera Road  Palam Vihar Halt  \
# 0           Smartworld One DXP          800.0            2500.0
# 1                    M3M Crown          550.0           54500.0
# 2  Adani Brahma Samsara Vilasa         5300.0           54500.0
# 3                   Sobha City         1500.0           54500.0
# 4     Signature Global City 93        54500.0           54500.0
#
#    DPSG Palam Vihar  Park Hospital  Gurgaon Railway Station  \
# 0            3100.0         3100.0                   4900.0
# 1           54500.0        54500.0                  54500.0
# 2           54500.0        54500.0                   2500.0
# 3           54500.0        54500.0                   6500.0
# 4           54500.0         5500.0                  54500.0
#
#    The NorthCap University  Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# 0                   5400.0       1200.0                           7700.0
# 1                   6700.0       3800.0                          54500.0
# 2                   8800.0      54500.0                          54500.0
# 3                   6700.0       5100.0                          54500.0
# 4                  54500.0      54500.0                          54500.0
#
#    Dwarka Sector 21, Metro Station  ...  The Shri Ram School Aravali  \
# 0                           7200.0  ...                      54500.0
# 1                          54500.0  ...                      54500.0
# 2                          54500.0  ...                      54500.0
# 3                           8100.0  ...                      54500.0
# 4                          54500.0  ...                      54500.0
#
#    Taj City Centre Gurugram  Minda Industries  Corporate Office  \
# 0                   54500.0                             54500.0
# 1                   54500.0                             54500.0
# 2                   54500.0                             54500.0
# 3                   54500.0                             54500.0
# 4                   54500.0                             54500.0
#
#    Rampura Flyover, Naurangpur Rd  Manesar toll plaza - Kherki Daula  \
# 0                         54500.0                            54500.0
# 1                         54500.0                            54500.0
# 2                         54500.0                            54500.0
# 3                         54500.0                            54500.0
# 4                         54500.0                            54500.0
#
#    Imt Manesar, Gurugram  Holiday Inn  Sector 84 Road  Skyview Corporate Park  \
# 0                54500.0      54500.0         54500.0                 54500.0
# 1                54500.0      54500.0         54500.0                 54500.0
# 2                54500.0      54500.0         54500.0                 54500.0
# 3                54500.0      54500.0         54500.0                 54500.0
# 4                54500.0      54500.0         54500.0                 54500.0
#
#                                                 Link
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
# [5 rows x 903 columns]

# %%
location_df.columns
# Out:
# Index(['PropertyName', 'Bajghera Road', 'Palam Vihar Halt', 'DPSG Palam Vihar',
#        'Park Hospital', 'Gurgaon Railway Station', 'The NorthCap University',
#        'Dwarka Expy', 'Hyatt Place Gurgaon Udyog Vihar',
#        'Dwarka Sector 21, Metro Station',
#        ...
#        'The Shri Ram School Aravali', 'Taj City Centre Gurugram',
#        'Minda Industries  Corporate Office', 'Rampura Flyover, Naurangpur Rd',
#        'Manesar toll plaza - Kherki Daula', 'Imt Manesar, Gurugram',
#        'Holiday Inn', 'Sector 84 Road', 'Skyview Corporate Park', 'Link'],
#       dtype='object', length=903)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Apply the scaler to the dataframe excluding 'PropertyName' and 'Link' columns
location_df_normalized = pd.DataFrame(scaler.fit_transform(location_df.drop(columns=['PropertyName', 'Link'])), columns=location_df.columns.drop(['PropertyName', 'Link']), index=location_df.index)

print("location_df_normalized:", location_df_normalized.shape)
location_df_normalized.head()
# Out:
# location_df_normalized: (246, 901)
#    Bajghera Road  Palam Vihar Halt  DPSG Palam Vihar  Park Hospital  \
# 0      -7.959290        -15.652476        -15.652476      -3.148555
# 1      -7.996942          0.063888          0.063888       0.328288
# 2      -7.281544          0.063888          0.063888       0.328288
# 3      -7.853863          0.063888          0.063888       0.328288
# 4       0.128478          0.063888          0.063888      -2.986212
#
#    Gurgaon Railway Station  The NorthCap University  Dwarka Expy  \
# 0                -2.902773                -3.145418    -3.724986
# 1                 0.376078                -3.053250    -3.529577
# 2                -3.061427                -2.904363     0.280892
# 3                -2.797004                -3.053250    -3.431873
# 4                 0.376078                 0.335702     0.280892
#
#    Hyatt Place Gurgaon Udyog Vihar  Dwarka Sector 21, Metro Station  \
# 0                       -10.240056                        -5.155383
# 1                         0.090313                         0.205673
# 2                         0.090313                         0.205673
# 3                         0.090313                        -5.053375
# 4                         0.090313                         0.205673
#
#    Pacific D21 Mall  ...  MCC Cricket Ground Dhankot  \
# 0         -6.021290  ...                         0.0
# 1         -6.008143  ...                         0.0
# 2          0.171075  ...                         0.0
# 3         -5.916112  ...                         0.0
# 4          0.171075  ...                         0.0
#
#    The Shri Ram School Aravali  Taj City Centre Gurugram  \
# 0                     0.063888                  0.063888
# 1                     0.063888                  0.063888
# 2                     0.063888                  0.063888
# 3                     0.063888                  0.063888
# 4                     0.063888                  0.063888
#
#    Minda Industries  Corporate Office  Rampura Flyover, Naurangpur Rd  \
# 0                            0.063888                        0.063888
# 1                            0.063888                        0.063888
# 2                            0.063888                        0.063888
# 3                            0.063888                        0.063888
# 4                            0.063888                        0.063888
#
#    Manesar toll plaza - Kherki Daula  Imt Manesar, Gurugram  Holiday Inn  \
# 0                           0.063888               0.063888          0.0
# 1                           0.063888               0.063888          0.0
# 2                           0.063888               0.063888          0.0
# 3                           0.063888               0.063888          0.0
# 4                           0.063888               0.063888          0.0
#
#    Sector 84 Road  Skyview Corporate Park
# 0        0.063888                0.063888
# 1        0.063888                0.063888
# 2        0.063888                0.063888
# 3        0.063888                0.063888
# 4        0.063888                0.063888
#
# [5 rows x 901 columns]

# %% [markdown]
# #### Step3 : Compute the cosine similarity matrix

# %%
location_cosine_similarity = cosine_similarity(location_df_normalized)

print("location_cosine_similarity:",location_cosine_similarity.shape)
# Out:
# location_cosine_similarity: (246, 246)

# %%
location_cosine_similarity
# Out:
# array([[ 1.        ,  0.15764489,  0.11576865, ..., -0.01559374,
#         -0.07070775, -0.07070775],
#        [ 0.15764489,  1.        ,  0.18226733, ..., -0.01277955,
#         -0.02025407, -0.02025407],
#        [ 0.11576865,  0.18226733,  1.        , ..., -0.01647841,
#         -0.02681601, -0.02681601],
#        ...,
#        [-0.01559374, -0.01277955, -0.01647841, ...,  1.        ,
#          0.05181754,  0.05181754],
#        [-0.07070775, -0.02025407, -0.02681601, ...,  0.05181754,
#          1.        ,  1.        ],
#        [-0.07070775, -0.02025407, -0.02681601, ...,  0.05181754,
#          1.        ,  1.        ]])

# %% [markdown]
# #### Step4 : Get the recommendations for a property based on `location`

# %%
x = location_df
x.head()
# Out:
#                   PropertyName  Bajghera Road  Palam Vihar Halt  \
# 0           Smartworld One DXP          800.0            2500.0
# 1                    M3M Crown          550.0           54500.0
# 2  Adani Brahma Samsara Vilasa         5300.0           54500.0
# 3                   Sobha City         1500.0           54500.0
# 4     Signature Global City 93        54500.0           54500.0
#
#    DPSG Palam Vihar  Park Hospital  Gurgaon Railway Station  \
# 0            3100.0         3100.0                   4900.0
# 1           54500.0        54500.0                  54500.0
# 2           54500.0        54500.0                   2500.0
# 3           54500.0        54500.0                   6500.0
# 4           54500.0         5500.0                  54500.0
#
#    The NorthCap University  Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# 0                   5400.0       1200.0                           7700.0
# 1                   6700.0       3800.0                          54500.0
# 2                   8800.0      54500.0                          54500.0
# 3                   6700.0       5100.0                          54500.0
# 4                  54500.0      54500.0                          54500.0
#
#    Dwarka Sector 21, Metro Station  ...  The Shri Ram School Aravali  \
# 0                           7200.0  ...                      54500.0
# 1                          54500.0  ...                      54500.0
# 2                          54500.0  ...                      54500.0
# 3                           8100.0  ...                      54500.0
# 4                          54500.0  ...                      54500.0
#
#    Taj City Centre Gurugram  Minda Industries  Corporate Office  \
# 0                   54500.0                             54500.0
# 1                   54500.0                             54500.0
# 2                   54500.0                             54500.0
# 3                   54500.0                             54500.0
# 4                   54500.0                             54500.0
#
#    Rampura Flyover, Naurangpur Rd  Manesar toll plaza - Kherki Daula  \
# 0                         54500.0                            54500.0
# 1                         54500.0                            54500.0
# 2                         54500.0                            54500.0
# 3                         54500.0                            54500.0
# 4                         54500.0                            54500.0
#
#    Imt Manesar, Gurugram  Holiday Inn  Sector 84 Road  Skyview Corporate Park  \
# 0                54500.0      54500.0         54500.0                 54500.0
# 1                54500.0      54500.0         54500.0                 54500.0
# 2                54500.0      54500.0         54500.0                 54500.0
# 3                54500.0      54500.0         54500.0                 54500.0
# 4                54500.0      54500.0         54500.0                 54500.0
#
#                                                 Link
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
# [5 rows x 903 columns]

# %%
location_df.set_index('PropertyName', inplace=True)
location_df.head()
# Out:
#                              Bajghera Road  Palam Vihar Halt  \
# PropertyName
# Smartworld One DXP                   800.0            2500.0
# M3M Crown                            550.0           54500.0
# Adani Brahma Samsara Vilasa         5300.0           54500.0
# Sobha City                          1500.0           54500.0
# Signature Global City 93           54500.0           54500.0
#
#                              DPSG Palam Vihar  Park Hospital  \
# PropertyName
# Smartworld One DXP                     3100.0         3100.0
# M3M Crown                             54500.0        54500.0
# Adani Brahma Samsara Vilasa           54500.0        54500.0
# Sobha City                            54500.0        54500.0
# Signature Global City 93              54500.0         5500.0
#
#                              Gurgaon Railway Station  The NorthCap University  \
# PropertyName
# Smartworld One DXP                            4900.0                   5400.0
# M3M Crown                                    54500.0                   6700.0
# Adani Brahma Samsara Vilasa                   2500.0                   8800.0
# Sobha City                                    6500.0                   6700.0
# Signature Global City 93                     54500.0                  54500.0
#
#                              Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# PropertyName
# Smartworld One DXP                1200.0                           7700.0
# M3M Crown                         3800.0                          54500.0
# Adani Brahma Samsara Vilasa      54500.0                          54500.0
# Sobha City                        5100.0                          54500.0
# Signature Global City 93         54500.0                          54500.0
#
#                              Dwarka Sector 21, Metro Station  \
# PropertyName
# Smartworld One DXP                                    7200.0
# M3M Crown                                            54500.0
# Adani Brahma Samsara Vilasa                          54500.0
# Sobha City                                            8100.0
# Signature Global City 93                             54500.0
#
#                              Pacific D21 Mall  ...  \
# PropertyName                                   ...
# Smartworld One DXP                     7400.0  ...
# M3M Crown                              7500.0  ...
# Adani Brahma Samsara Vilasa           54500.0  ...
# Sobha City                             8200.0  ...
# Signature Global City 93              54500.0  ...
#
#                              The Shri Ram School Aravali  \
# PropertyName
# Smartworld One DXP                               54500.0
# M3M Crown                                        54500.0
# Adani Brahma Samsara Vilasa                      54500.0
# Sobha City                                       54500.0
# Signature Global City 93                         54500.0
#
#                              Taj City Centre Gurugram  \
# PropertyName
# Smartworld One DXP                            54500.0
# M3M Crown                                     54500.0
# Adani Brahma Samsara Vilasa                   54500.0
# Sobha City                                    54500.0
# Signature Global City 93                      54500.0
#
#                              Minda Industries  Corporate Office  \
# PropertyName
# Smartworld One DXP                                      54500.0
# M3M Crown                                               54500.0
# Adani Brahma Samsara Vilasa                             54500.0
# Sobha City                                              54500.0
# Signature Global City 93                                54500.0
#
#                              Rampura Flyover, Naurangpur Rd  \
# PropertyName
# Smartworld One DXP                                  54500.0
# M3M Crown                                           54500.0
# Adani Brahma Samsara Vilasa                         54500.0
# Sobha City                                          54500.0
# Signature Global City 93                            54500.0
#
#                              Manesar toll plaza - Kherki Daula  \
# PropertyName
# Smartworld One DXP                                     54500.0
# M3M Crown                                              54500.0
# Adani Brahma Samsara Vilasa                            54500.0
# Sobha City                                             54500.0
# Signature Global City 93                               54500.0
#
#                              Imt Manesar, Gurugram  Holiday Inn  \
# PropertyName
# Smartworld One DXP                         54500.0      54500.0
# M3M Crown                                  54500.0      54500.0
# Adani Brahma Samsara Vilasa                54500.0      54500.0
# Sobha City                                 54500.0      54500.0
# Signature Global City 93                   54500.0      54500.0
#
#                              Sector 84 Road  Skyview Corporate Park  \
# PropertyName
# Smartworld One DXP                  54500.0                 54500.0
# M3M Crown                           54500.0                 54500.0
# Adani Brahma Samsara Vilasa         54500.0                 54500.0
# Sobha City                          54500.0                 54500.0
# Signature Global City 93            54500.0                 54500.0
#
#                                                                           Link
# PropertyName
# Smartworld One DXP           https://www.99acres.com/smartworld-one-dxp-sec...
# M3M Crown                    https://www.99acres.com/m3m-crown-sector-111-g...
# Adani Brahma Samsara Vilasa  https://www.99acres.com/adani-brahma-samsara-v...
# Sobha City                   https://www.99acres.com/sobha-city-sector-108-...
# Signature Global City 93     https://www.99acres.com/signature-global-city-...
#
# [5 rows x 902 columns]

# %%
def get_location_based_recommendations(property_name, top_n=10):
    print("property_name:",property_name)
    # Get the index of the property that matches the property_name
    idx = location_df.index.get_loc(property_name)
    print("idx:",idx)
    
    # Get the pairwise similarity scores of all properties with that property
    sim_scores = list(enumerate(location_cosine_similarity[idx]))
    
    # Sort the properties based on the similarity scores (increasing distance)
    sim_scores = sorted(sim_scores, key=lambda x: x[1])
    
    # Get the scores of the top_n most similar properties
    sim_scores = sim_scores[1:top_n+1]
    
    # Get the property indices
    property_indices = [i[0] for i in sim_scores]
    
    # Return the top_n most similar properties
    return location_df.iloc[property_indices]

# Example usage
get_location_based_recommendations('Smartworld One DXP', top_n=5)
# Out:
# property_name: Smartworld One DXP
# idx: 0
#                          Bajghera Road  Palam Vihar Halt  DPSG Palam Vihar  \
# PropertyName
# M3M Antalya Hills              54500.0           54500.0           54500.0
# Suncity Vatsal Valley          54500.0           54500.0           54500.0
# Trump Tower                    54500.0           54500.0           54500.0
# La Vida by Tata Housing        54500.0           54500.0           54500.0
# BPTP Terra                     54500.0           54500.0           54500.0
#
#                          Park Hospital  Gurgaon Railway Station  \
# PropertyName
# M3M Antalya Hills              54500.0                  54500.0
# Suncity Vatsal Valley          54500.0                  54500.0
# Trump Tower                    54500.0                  54500.0
# La Vida by Tata Housing        54500.0                  54500.0
# BPTP Terra                     54500.0                  54500.0
#
#                          The NorthCap University  Dwarka Expy  \
# PropertyName
# M3M Antalya Hills                        54500.0      54500.0
# Suncity Vatsal Valley                    54500.0      54500.0
# Trump Tower                              54500.0      54500.0
# La Vida by Tata Housing                  54500.0      54500.0
# BPTP Terra                               54500.0      54500.0
#
#                          Hyatt Place Gurgaon Udyog Vihar  \
# PropertyName
# M3M Antalya Hills                                54500.0
# Suncity Vatsal Valley                            54500.0
# Trump Tower                                      54500.0
# La Vida by Tata Housing                          54500.0
# BPTP Terra                                       54500.0
#
#                          Dwarka Sector 21, Metro Station  Pacific D21 Mall  \
# PropertyName
# M3M Antalya Hills                                54500.0           54500.0
# Suncity Vatsal Valley                            54500.0           54500.0
# Trump Tower                                      54500.0           54500.0
# La Vida by Tata Housing                          54500.0           54500.0
# BPTP Terra                                       54500.0           54500.0
#
#                          ...  The Shri Ram School Aravali  \
# PropertyName             ...
# M3M Antalya Hills        ...                      54500.0
# Suncity Vatsal Valley    ...                      54500.0
# Trump Tower              ...                      54500.0
# La Vida by Tata Housing  ...                      54500.0
# BPTP Terra               ...                      54500.0
#
#                          Taj City Centre Gurugram  \
# PropertyName
# M3M Antalya Hills                         54500.0
# Suncity Vatsal Valley                     54500.0
# Trump Tower                               54500.0
# La Vida by Tata Housing                   54500.0
# BPTP Terra                                54500.0
#
#                          Minda Industries  Corporate Office  \
# PropertyName
# M3M Antalya Hills                                   54500.0
# Suncity Vatsal Valley                               54500.0
# Trump Tower                                         54500.0
# La Vida by Tata Housing                             54500.0
# BPTP Terra                                          54500.0
#
#                          Rampura Flyover, Naurangpur Rd  \
# PropertyName
# M3M Antalya Hills                               54500.0
# Suncity Vatsal Valley                           54500.0
# Trump Tower                                     54500.0
# La Vida by Tata Housing                         54500.0
# BPTP Terra                                      54500.0
#
#                          Manesar toll plaza - Kherki Daula  \
# PropertyName
# M3M Antalya Hills                                  54500.0
# Suncity Vatsal Valley                              54500.0
# Trump Tower                                        54500.0
# La Vida by Tata Housing                            54500.0
# BPTP Terra                                         54500.0
#
#                          Imt Manesar, Gurugram  Holiday Inn  Sector 84 Road  \
# PropertyName
# M3M Antalya Hills                      54500.0      54500.0         54500.0
# Suncity Vatsal Valley                  54500.0      54500.0         54500.0
# Trump Tower                            54500.0      54500.0         54500.0
# La Vida by Tata Housing                54500.0      54500.0         54500.0
# BPTP Terra                             54500.0      54500.0         54500.0
#
#                          Skyview Corporate Park  \
# PropertyName
# M3M Antalya Hills                       54500.0
# Suncity Vatsal Valley                   54500.0
# Trump Tower                             54500.0
# La Vida by Tata Housing                 54500.0
# BPTP Terra                              54500.0
#
#                                                                       Link
# PropertyName
# M3M Antalya Hills        https://www.99acres.com/m3m-antalya-hills-sect...
# Suncity Vatsal Valley    https://www.99acres.com/suncity-vatsal-valley-...
# Trump Tower              https://www.99acres.com/trump-tower-sector-65-...
# La Vida by Tata Housing  https://www.99acres.com/la-vida-by-tata-housin...
# BPTP Terra               https://www.99acres.com/bptp-terra-sector-37d-...
#
# [5 rows x 902 columns]

# %% [markdown]
# ----

# %% [markdown]
# ## **Final Recommendation System**
#
# - We will use a weighted average of the three similarity matrices to get the final recommendations.
# - The weights are manually set to 30, 20, and 8 respectively.
# - The weights can be adjusted based on the importance of each similarity matrix.

# %%
def recommend_properties_with_scores(property_name, cosine_sim_matrix, top_n=5):

    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosine_sim_matrix[location_df.index.get_loc(property_name)]))
    
    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the indices and scores of the top_n most similar properties
    top_indices = [i[0] for i in sorted_scores[1:top_n+1]]
    top_scores = [i[1] for i in sorted_scores[1:top_n+1]]
    
    # Retrieve the names and links of the top properties using the indices
    top_properties = location_df.index[top_indices].tolist()
    top_links = location_df['Link'].iloc[top_indices].tolist()
    
    # Create a dataframe with the results
    recommendations_df = pd.DataFrame({
        'PropertyName': top_properties,
        'SimilarityScore': top_scores,
        'Link': top_links
    })
    
    return recommendations_df

# %%
location_df.columns
# Out:
# Index(['Bajghera Road', 'Palam Vihar Halt', 'DPSG Palam Vihar',
#        'Park Hospital', 'Gurgaon Railway Station', 'The NorthCap University',
#        'Dwarka Expy', 'Hyatt Place Gurgaon Udyog Vihar',
#        'Dwarka Sector 21, Metro Station', 'Pacific D21 Mall',
#        ...
#        'The Shri Ram School Aravali', 'Taj City Centre Gurugram',
#        'Minda Industries  Corporate Office', 'Rampura Flyover, Naurangpur Rd',
#        'Manesar toll plaza - Kherki Daula', 'Imt Manesar, Gurugram',
#        'Holiday Inn', 'Sector 84 Road', 'Skyview Corporate Park', 'Link'],
#       dtype='object', length=902)

# %%
cosine_sim_matrix = 30*location_cosine_similarity + 20*price_cosine_similarity + 8*facilities_cosine_similarity

# Test the recommender function using a property name
recommend_properties_with_scores('Smartworld One DXP',cosine_sim_matrix, top_n =5)
# Out:
#               PropertyName  SimilarityScore  \
# 0               Sobha City        25.446834
# 1         Puri Emerald Bay        19.976499
# 2  AIPL The Peaceful Homes        19.832601
# 3               Ireo Skyon        19.723409
# 4           M3M Golf Hills        19.315110
#
#                                                 Link
# 0  https://www.99acres.com/sobha-city-sector-108-...
# 1  https://www.99acres.com/puri-emerald-bay-secto...
# 2  https://www.99acres.com/aipl-the-peaceful-home...
# 3  https://www.99acres.com/ireo-skyon-sector-60-g...
# 4  https://www.99acres.com/m3m-golf-hills-sector-...

# %%
# Save the combined matrix
np.save('../backend/models/cosine_sim_matrix.npy', cosine_sim_matrix)

# %% [markdown]
# End
#
# ---

# %% [markdown]
# ## recommend API

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
import pandas as pd
import numpy as np
import os

class PropertyRequest(BaseModel):
    property_name: str


app = FastAPI()
def recommend_properties_with_scores(df, property_name, cosine_sim_matrix, top_n=5):
    # Check if property_name exists in the dataframe
    if property_name not in df.index:
        raise ValueError(f"Property '{property_name}' not found in the dataframe.")

    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosine_sim_matrix[df.index.get_loc(property_name)]))
    
    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the indices and scores of the top_n most similar properties
    top_indices = [i[0] for i in sorted_scores[1:top_n+1]]
    
    # Retrieve the names and links of the top properties using the indices
    top_properties = df.index[top_indices].tolist()
    top_links = df['Link'].iloc[top_indices].tolist()
    
    # Create a dataframe with the results
    recommendations_df = pd.DataFrame({
        'PropertyName': top_properties,
        'Link': top_links
    })
    
    return recommendations_df.to_dict(orient='records')


@app.post('/recommend_properties')
async def recommend_properties(request: PropertyRequest):
    property_name = request.property_name
    
    location_df.set_index('PropertyName', inplace=True)


    if property_name not in location_df.index:
        print("Property not found")
        raise HTTPException(status_code=404, detail="Property not found")
    
    return recommend_properties_with_scores(location_df, property_name, cosine_sim_matrix, top_n=5)

# %% [markdown]
# ---

# %% [markdown]
# ## property API

# %%
# load the location_df
location_df = pd.read_pickle("../backend/models/location_df.pkl")
print("Loaded location_df:", location_df.shape)
location_df.head()
# Out:
# Loaded location_df: (246, 903)
#                   PropertyName  Bajghera Road  Palam Vihar Halt  \
# 0           Smartworld One DXP          800.0            2500.0
# 1                    M3M Crown          550.0           54500.0
# 2  Adani Brahma Samsara Vilasa         5300.0           54500.0
# 3                   Sobha City         1500.0           54500.0
# 4     Signature Global City 93        54500.0           54500.0
#
#    DPSG Palam Vihar  Park Hospital  Gurgaon Railway Station  \
# 0            3100.0         3100.0                   4900.0
# 1           54500.0        54500.0                  54500.0
# 2           54500.0        54500.0                   2500.0
# 3           54500.0        54500.0                   6500.0
# 4           54500.0         5500.0                  54500.0
#
#    The NorthCap University  Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# 0                   5400.0       1200.0                           7700.0
# 1                   6700.0       3800.0                          54500.0
# 2                   8800.0      54500.0                          54500.0
# 3                   6700.0       5100.0                          54500.0
# 4                  54500.0      54500.0                          54500.0
#
#    Dwarka Sector 21, Metro Station  ...  The Shri Ram School Aravali  \
# 0                           7200.0  ...                      54500.0
# 1                          54500.0  ...                      54500.0
# 2                          54500.0  ...                      54500.0
# 3                           8100.0  ...                      54500.0
# 4                          54500.0  ...                      54500.0
#
#    Taj City Centre Gurugram  Minda Industries  Corporate Office  \
# 0                   54500.0                             54500.0
# 1                   54500.0                             54500.0
# 2                   54500.0                             54500.0
# 3                   54500.0                             54500.0
# 4                   54500.0                             54500.0
#
#    Rampura Flyover, Naurangpur Rd  Manesar toll plaza - Kherki Daula  \
# 0                         54500.0                            54500.0
# 1                         54500.0                            54500.0
# 2                         54500.0                            54500.0
# 3                         54500.0                            54500.0
# 4                         54500.0                            54500.0
#
#    Imt Manesar, Gurugram  Holiday Inn  Sector 84 Road  Skyview Corporate Park  \
# 0                54500.0      54500.0         54500.0                 54500.0
# 1                54500.0      54500.0         54500.0                 54500.0
# 2                54500.0      54500.0         54500.0                 54500.0
# 3                54500.0      54500.0         54500.0                 54500.0
# 4                54500.0      54500.0         54500.0                 54500.0
#
#                                                 Link
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
# [5 rows x 903 columns]

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
import pandas as pd

app = FastAPI()

class LocationRadiusRequest(BaseModel):
    location: str
    radius: float

@app.post('/get_apartments_within_radius')
async def get_apartments_within_radius(request: LocationRadiusRequest):
    location = request.location
    radius = request.radius

    radius_in_meters = radius * 1000

    if location in location_df.columns:
        filtered_df = location_df[location_df[location] <= radius_in_meters]
        apartments_within_radius = filtered_df[['PropertyName', 'Link']]
        if not apartments_within_radius.empty:
            apartments_within_radius_json = apartments_within_radius.to_json(orient='records')
            return {"apartments_within_radius": apartments_within_radius_json}
        else:
            raise HTTPException(status_code=404, detail="No apartments found within the specified radius")
    else:
        raise HTTPException(status_code=400, detail="Invalid Location")

# %% [markdown]
# ---
